# %%
import pandas as pd
#This is an excel that contains the tables for parametric equations from Koushan's paper
df_nrs = pd.read_excel('Koushan_Netwon-Rader-ANN-Regression-Formula.perpage.xlsx')

print(df_nrs.columns.tolist())
# Out:
# ['International Conference on Fast Sea Transportation', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7']

# %%
df_nrs
# Out:
#    International Conference on Fast Sea Transportation Unnamed: 1 Unnamed: 2  \
# 0         FAST’2005, June 2005, St.Petersburg, Russia         NaN        NaN
# 1   Table 2: Constants required for prediction of ...         NaN        NaN
# 2                                                   k         NaN         Dk
# 3                                                   1    1.015801        NaN
# 4                                                   2    3.829787        NaN
# 5                                                   3    1.730769        NaN
# 6                                                   4         2.4        NaN
# 7                                                 NaN         NaN        NaN
# 8                              G = -0.768344044685363         NaN        NaN
# 9                               L = 3.291398525238030         NaN        NaN
# 10                             C = -0.377740830183029         NaN        NaN
# 11                                                NaN         NaN        NaN
# 12                                                NaN         NaN        NaN
# 13                                                NaN         NaN        NaN
# 14                                                NaN         NaN        NaN
# 15                                                NaN         NaN        NaN
# 16                                                NaN         NaN        NaN
# 17                                                NaN         NaN        NaN
# 18                                                NaN           i       h1,i
# 19                                                NaN           1  -0.087731
# 20                                                NaN           2   0.136592
# 21                                                NaN           3   -2.37121
# 22                                                NaN           4   1.338524
# 23                                                NaN           5  -4.371421
# 24                                                NaN           6   -5.17178
# 25                                                NaN           7  -2.002248
# 26                                                NaN           8  -0.495176
# 27                                                NaN           9   1.920007
# 28                                                 10         NaN  -0.146149
# 29                                                 11         NaN  -4.512323
# 30                                                 12         NaN  -2.852176
# 31                                                 13         NaN   4.315288
# 32                                                 14         NaN  -0.764148
# 33                                                 15         NaN  -1.635938
# 34  Table 3: Constants required for prediction of ...         NaN        NaN
# 35                                                  k          Dk        NaN
# 36                                                  1    1.132788        NaN
# 37                                                  2    3.829787        NaN
# 38                                                  3    1.730769        NaN
# 39                                                NaN         NaN        NaN
# 40                              G =-0.738784790039062         NaN        NaN
# 41                              L = 3.224303960800170         NaN        NaN
# 42                             C = -0.376195490360260         NaN        NaN
# 43                                                NaN           i        NaN
# 44                                                NaN           1  -0.124825
# 45                                                NaN           2  -2.384441
# 46                                                NaN           3   2.234082
# 47                                                NaN           4  -0.579336
# 48                                                NaN           5  -0.223387
# 49                                                  5         NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0         NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN
# 2         NaN         Ek          i        O i         ai
# 3   -1.407901        NaN          1   1.317354  -1.148691
# 4   -2.738298        NaN          2  -0.738122  -0.193716
# 5        -2.7        NaN          3  -0.941667   0.608081
# 6        -1.5        NaN          4  -0.804431  -0.100771
# 7         NaN        NaN          5  -0.727643   0.913926
# 8         NaN        NaN          6   0.933406  -0.399212
# 9         NaN        NaN          7  -0.436863  -0.015545
# 10        NaN        NaN          8  -0.744884  -0.618124
# 11        NaN        NaN          9   0.711937   0.812608
# 12        NaN        NaN         10   0.670404  -0.581251
# 13        NaN        NaN         11   1.441804   1.202768
# 14        NaN        NaN         12   0.974518   0.364289
# 15        NaN        NaN         13   1.001717   0.391402
# 16        NaN        NaN         14  -0.588005  -0.810351
# 17        NaN        NaN         15   0.695904  -0.708706
# 18        NaN       h2,i        NaN       h3,i       h4,i
# 19        NaN   0.093006        NaN   0.401366   0.267277
# 20        NaN   0.212323        NaN    0.08673   0.973016
# 21        NaN  -0.130272        NaN   1.014987  -0.822617
# 22        NaN  -0.334298        NaN  -0.895096   0.788783
# 23        NaN  -0.034236        NaN   2.684856   0.968316
# 24        NaN  -0.546013        NaN   1.749251  -1.032036
# 25        NaN   0.508135        NaN    1.54262  -0.667989
# 26        NaN   0.389427        NaN  -0.672402   0.157832
# 27        NaN   0.221785        NaN  -0.656296      1.214
# 28        NaN   1.363635        NaN  -0.819712   0.097338
# 29        NaN   0.019759        NaN   2.710045   0.736026
# 30        NaN  -0.174429        NaN   1.185968  -0.212096
# 31        NaN   0.546207        NaN  -1.339087   1.069359
# 32        NaN   1.575307        NaN  -0.405051   0.144643
# 33        NaN    0.45023        NaN   0.142536   0.243727
# 34        NaN        NaN        NaN        NaN        NaN
# 35         Ek          i        NaN        O i         ai
# 36  -1.692951          1        NaN   0.940852  -0.270165
# 37  -2.738298          2        NaN   1.826129   1.490584
# 38       -2.7          3        NaN  -1.893095   2.630163
# 39        NaN          4        NaN   0.675479    0.36831
# 40        NaN          5        NaN    0.97199   0.286899
# 41        NaN        NaN        NaN        NaN        NaN
# 42        NaN        NaN        NaN        NaN        NaN
# 43       h1,i       h2,i        NaN       h3,i        NaN
# 44        NaN   0.103371        NaN   0.865557        NaN
# 45        NaN   0.085134        NaN   1.728574        NaN
# 46        NaN  -0.431567        NaN  -1.169072        NaN
# 47        NaN   0.385408        NaN  -0.127584        NaN
# 48        NaN  -0.373791        NaN  -0.299132        NaN
# 49        NaN        NaN        NaN        NaN        NaN

# %%
import math
def kt_nrs(J,AE_AO,pitch_over_diameter,sigma,df_nrs):
    inner_sum = 0
    outer_sum = 0
    pod = pitch_over_diameter 
    for i in range(15):
        inner_sum += df_nrs['Unnamed: 7'][3+i]+df_nrs['Unnamed: 2'][19+i]*(1.015801*J-1.407901)+df_nrs['Unnamed: 4'][19+i]*(3.829787*AE_AO-2.738298)+df_nrs['Unnamed: 6'][19+i]*(1.73076927661895*pod-2.7)+df_nrs['Unnamed: 7'][19+i]*(2.4*sigma-1.5)
        outer_sum += math.tanh(inner_sum)*df_nrs['Unnamed: 6'][3+i]
    y = (math.tanh(outer_sum-0.377740830183029)+(0.768344044685363))/3.291398525238030
    return y
#Calculate KT for a respresentative value:
pbyd = 2.04 #P/D ratio
sigma = 0.5 #cavitation number
ear = 0.95 #expanded area ratio
kt_nrs(1.5,ear,pbyd,sigma,df_nrs) #1.5 advance coefficient.
# Out:
# 0.5368052251517991

# %%
df_nrs_2 = pd.read_excel('Koushan_Netwon-Rader-ANN-Regression-Formula.perpage.xlsx', 'Page 6')
df_nrs_2
# Out:
#    International Conference on Fast Sea Transportation Unnamed: 1 Unnamed: 2  \
# 0         FAST’2005, June 2005, St.Petersburg, Russia         NaN        NaN
# 1   Table 4: Constants required for prediction of ...         NaN        NaN
# 2                                                   k         NaN         Dk
# 3                                                   1    1.015801        NaN
# 4                                                   2    3.829787        NaN
# 5                                                   3    1.730769        NaN
# 6                                                   4         2.4        NaN
# 7                                                 NaN         NaN        NaN
# 8                              G = -0.847399175167083         NaN        NaN
# 9                               L = 10.52016377449030         NaN        NaN
# 10                             C = -1.040541768074030         NaN        NaN
# 11                                                NaN         NaN        NaN
# 12                                                NaN         NaN        NaN
# 13                                                NaN         NaN        NaN
# 14                                                NaN         NaN        NaN
# 15                                                NaN         NaN        NaN
# 16                                                NaN         NaN        NaN
# 17                                                NaN         NaN        NaN
# 18                                                NaN           i       h1,i
# 19                                                NaN           1  -0.240043
# 20                                                NaN           2   4.257379
# 21                                                NaN           3   4.661829
# 22                                                NaN           4  -2.136205
# 23                                                NaN           5    5.35525
# 24                                                NaN           6   0.191873
# 25                                                NaN           7   1.526025
# 26                                                NaN           8   0.534627
# 27                                                NaN           9    4.32375
# 28                                                 10         NaN   0.989771
# 29                                                 11         NaN   4.051303
# 30                                                 12         NaN   1.492992
# 31                                                 13         NaN    3.40587
# 32                                                 14         NaN  -1.642315
# 33                                                 15         NaN  -0.764876
# 34  Table 5: Constants required for prediction of ...         NaN        NaN
# 35                                                  k          Dk         Ek
# 36                                                  1    1.132788  -1.692951
# 37                                                  2    3.829787  -2.738298
# 38                                                  3    1.730769       -2.7
# 39                                                NaN         NaN        NaN
# 40                                           G = -0.9         NaN        NaN
# 41                              L = 10.59758543968200         NaN        NaN
# 42                              C = 0.226830631494522         NaN        NaN
# 43                                                NaN           i       h1,i
# 44                                                NaN           1   1.662292
# 45                                                NaN           2   0.045066
# 46                                                NaN           3   0.412147
# 47                                                NaN           4   0.164922
# 48                                                NaN           5   1.738353
# 49                                                  6         NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0          NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN
# 2          NaN         Ek          i        O i         ai
# 3    -1.407901        NaN          1   0.969992    0.05313
# 4    -2.738298        NaN          2   0.231119  -1.052649
# 5    -2.700000        NaN          3   1.088238   0.451427
# 6    -1.500000        NaN          4   0.505152  -1.368094
# 7          NaN        NaN          5  -1.071812   0.452628
# 8          NaN        NaN          6   0.992359   0.340347
# 9          NaN        NaN          7   1.214749   0.638039
# 10         NaN        NaN          8   0.371759  -0.326673
# 11         NaN        NaN          9  -0.970896   -1.39367
# 12         NaN        NaN         10   0.547688   0.640973
# 13         NaN        NaN         11  -0.162237   0.774095
# 14         NaN        NaN         12  -0.666322   0.585491
# 15         NaN        NaN         13  -0.647845  -0.583688
# 16         NaN        NaN         14   -1.08109   0.614605
# 17         NaN        NaN         15   0.155757  -0.351224
# 18         NaN       h2,i        NaN       h3,i       h4,i
# 19         NaN  -0.168752        NaN  -0.135896  -1.043172
# 20         NaN   0.002107        NaN  -2.515236   -1.65326
# 21         NaN   0.559998        NaN  -1.431215   1.101807
# 22         NaN  -0.108279        NaN   1.294241  -0.081456
# 23         NaN   0.566431        NaN  -1.808804   1.026859
# 24         NaN   0.402996        NaN   0.512346  -0.521809
# 25         NaN   0.188212        NaN  -0.427222   1.122765
# 26         NaN  -0.875299        NaN  -1.236308   0.604218
# 27         NaN  -0.092469        NaN  -2.450196   -0.72387
# 28         NaN  -0.878277        NaN   0.170171  -0.296524
# 29         NaN  -0.044921        NaN  -1.689988   1.831228
# 30         NaN  -0.288999        NaN  -0.202796  -0.292662
# 31         NaN   0.317587        NaN  -1.321955   0.191683
# 32         NaN  -0.230709        NaN   0.398518  -0.706239
# 33         NaN   1.591476        NaN  -0.645161   0.231215
# 34         NaN        NaN        NaN        NaN        NaN
# 35         NaN          i        NaN        O i         ai
# 36         NaN          1        NaN  -3.202844    2.70068
# 37         NaN          2        NaN  -0.370149  -0.347794
# 38         NaN          3        NaN  -0.624824   0.170037
# 39         NaN          4        NaN   0.904308   1.116573
# 40         NaN          5        NaN   -1.99548  -1.274008
# 41         NaN        NaN        NaN        NaN        NaN
# 42         NaN        NaN        NaN        NaN        NaN
# 43         NaN       h2,i        NaN       h3,i        NaN
# 44         NaN  -0.318319        NaN   -1.39907        NaN
# 45         NaN    0.68406        NaN   0.614232        NaN
# 46         NaN  -0.227015        NaN  -1.119494        NaN
# 47         NaN   0.199502        NaN  -0.272222        NaN
# 48         NaN  -0.122753        NaN  -1.131857        NaN
# 49         NaN        NaN        NaN        NaN        NaN

# %%
def kq_nrs(J,AE_AO,pitch_over_diameter,sigma,df_nrs):
    inner_sum = 0
    outer_sum = 0
    pod = pitch_over_diameter 
    for i in range(15):
        inner_sum += df_nrs_2['Unnamed: 7'][3+i]+df_nrs_2['Unnamed: 2'][19+i]*(1.015801*J-1.407901)+df_nrs_2['Unnamed: 4'][19+i]*(3.829787*AE_AO-2.738298)+df_nrs_2['Unnamed: 6'][19+i]*(1.73076927661895*pod-2.7)+df_nrs_2['Unnamed: 7'][19+i]*(2.4*sigma-1.5)
        outer_sum += math.tanh(inner_sum)*df_nrs_2['Unnamed: 6'][3+i]
    y = (math.tanh(outer_sum-1.040541768074030)+(0.847399175167083))/10.52016377449030
    return y

# %%
import numpy as np
#Compute KQ
def calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1):
    m = len(O1)
    n = 4
    # Calculate the inner sum
    inner_sum = np.zeros(m)
    for i in range(m):
        inner_sum[i] = a1[i]
        for k in range(n):
            inner_sum[i] += h1[k][i] * (D1[k] * X1[k] + E1[k])
    
    # Calculate the outer sum
    outer_sum = C1 + np.sum(O1 * np.tanh(inner_sum))
    
    # Calculate Y
    Y = (np.tanh(outer_sum) - G1) / L1
    
    return Y

#Compute KT
def calculate_Y2(C2, O2, a2, h2, D2, X2, E2, G2, L2):
    m = len(O2)
    n = 4
    # Calculate the inner sum
    inner_sum = np.zeros(m)
    for i in range(m):
        inner_sum[i] = a2[i]
        for k in range(n):
            inner_sum[i] += h2[k][i] * (D2[k] * X2[k] + E2[k])
    
    # Calculate the outer sum
    outer_sum = C2 + np.sum(O2 * np.tanh(inner_sum))
    
    # Calculate Y
    Y = (np.tanh(outer_sum) - G2) / L2
    
    return Y

# %%
import cupy as cp

#Compute KQ
def calculate_Y1_cupy(C1, O1, a1, h1, D1, X1, E1, G1, L1):
    X11 = cp.asarray(X1)
    C11 = cp.asarray(C1)
    O11 = cp.asarray(O1)
    a11 = cp.asarray(a1)
    h11 = cp.asarray(h1)
    D11 = cp.asarray(D1)
    E11 = cp.asarray(E1)
    G11 = cp.asarray(G1)
    L11 = cp.asarray(L1)
    m = len(O1)
    n = 4
    # Calculate the inner sum
    inner_sum = cp.zeros(m)
    for i in range(m):
        inner_sum[i] = a11[i]
        for k in range(n):
            inner_sum[i] += h11[k][i] * (D11[k] * X11[k] + E11[k])
    
    # Calculate the outer sum
    outer_sum = C11 + cp.sum(O11 * cp.tanh(inner_sum))
    
    # Calculate Y
    Y = (cp.tanh(outer_sum) - G11) / L11
    
    return Y

#Compute KT
def calculate_Y2_cupy(C2, O2, a2, h2, D2, X2, E2, G2, L2):
    X22 = cp.asarray(X2)
    C22 = cp.asarray(C2)
    O22 = cp.asarray(O2)
    a22 = cp.asarray(a2)
    h22 = cp.asarray(h2)
    D22 = cp.asarray(D2)
    E22 = cp.asarray(E2)
    G22 = cp.asarray(G2)
    L22 = cp.asarray(L2)
    m = len(O2)
    n = 4
    # Calculate the inner sum
    inner_sum = cp.zeros(m)
    for i in range(m):
        inner_sum[i] = a22[i]
        for k in range(n):
            inner_sum[i] += h22[k][i] * (D22[k] * X22[k] + E22[k])
    
    # Calculate the outer sum
    outer_sum = C22 + cp.sum(O22 * cp.tanh(inner_sum))
    
    # Calculate Y
    Y = (cp.tanh(outer_sum) - G22) / L22
    
    return Y

# %%
# intialize constants
C1 =  -1.040541768074030
G1 = -0.847399175167083
L1 = 10.52016377449030

C2 =  -0.377740830183029
G2 = -0.768344044685363
L2 = 3.291398525238030

O1 = np.zeros(15)
for i in range(15):
    O1[i] = df_nrs_2['Unnamed: 6'][3+i]
    
O2 = np.zeros(15)
for i in range(15):
    O2[i] = df_nrs['Unnamed: 6'][3+i]

a1 = np.zeros(15)
for i in range(15):
    a1[i] = df_nrs_2['Unnamed: 7'][3+i]
    
a2 = np.zeros(15)
for i in range(15):
    a2[i] = df_nrs['Unnamed: 7'][3+i]

h1 = np.zeros((4,15))
for i in range(15):
    h1[0][i] = df_nrs_2['Unnamed: 2'][19+i] 
    h1[1][i] = df_nrs_2['Unnamed: 4'][19+i] 
    h1[2][i] = df_nrs_2['Unnamed: 6'][19+i] 
    h1[3][i] = df_nrs_2['Unnamed: 7'][19+i] 
    
h2 = np.zeros((4,15))
for i in range(15):
    h2[0][i] = df_nrs['Unnamed: 2'][19+i] 
    h2[1][i] = df_nrs['Unnamed: 4'][19+i] 
    h2[2][i] = df_nrs['Unnamed: 6'][19+i] 
    h2[3][i] = df_nrs['Unnamed: 7'][19+i]
    
D1 = np.zeros(4)
for i in range(4):
    D1[i] = df_nrs_2['Unnamed: 1'][3+i]
    
D2 = np.zeros(4)
for i in range(4):
    D2[i] = df_nrs['Unnamed: 1'][3+i]
    
E1 = np.zeros(4)
for i in range(4):
    E1[i] = df_nrs_2['Unnamed: 3'][3+i]
    
E2 = np.zeros(4)
for i in range(4):
    E2[i] = df_nrs['Unnamed: 3'][3+i]

# %%
#Plot KQ curves to verify with the regression equations.
import matplotlib.pyplot as plt

J = np.linspace(0.5, 2.25, num=25)
J1 = np.linspace(0.75, 1.75, num=20)
J2 = np.linspace(0.5, 1.25, num=15)
J3 = np.linspace(0.5, 1.05, num=11)

kq = np.zeros(25)
X1 = np.zeros(4)
for i in range(len(J)):
    X1[1] = 0.95
    X1[2] = 2.04
    X1[3] = 0.5
    X1[0] = J[i]
    kq[i] = 10*calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
kq1 = np.zeros(20)
for i in range(len(J1)):
    X1[1] = 0.95
    X1[2] = 1.65
    X1[3] = 0.5
    X1[0] = J1[i]
    kq1[i] = 10*calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
kq2 = np.zeros(15)
for i in range(len(J2)):
    X1[1] = 0.95
    X1[2] = 1.24
    X1[3] = 0.5
    X1[0] = J2[i]
    kq2[i] = 10*calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
kq3 = np.zeros(11)
for i in range(len(J3)):
    X1[1] = 0.95
    X1[2] = 1.04
    X1[3] = 0.5
    X1[0] = J3[i]
    kq3[i] = 10*calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)

plt.scatter(J, kq,marker = 'x', color = 'blue')
plt.scatter(J1, kq1,marker = 'x', color = 'blue')
plt.scatter(J2, kq2,marker = 'x', color = 'blue')
plt.scatter(J3, kq3,marker = 'x', color = 'blue')

# %%
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt

# Given points
vboat = np.array([0, 2.5, 5, 7.5, 10, 15, 20, 30, 40])
resistance = np.array([0, 475, 1900, 4275, 6900, 6000, 5740, 10125, 24000])

# Cubic spline interpolation
spline = interpolate.CubicSpline(vboat, resistance)

# Evaluate the spline at new points
new_vboat = np.linspace(0, 40, 100)
new_resistance = spline(new_vboat)

# Plot the cubic spline
plt.plot(new_vboat, new_resistance, label='Cubic spline')

# Plot the given points
plt.scatter(vboat, resistance, label='Given points')

# Set the axis labels and title
plt.xlabel('vboat (m/s)')
plt.ylabel('Resistance (N)')
plt.title('Boat Resistance and Thrust Matching Curve')

# Show the legend
plt.legend()

patm = 101300
rho = 1025
g = 9.81
h = 1
po = patm + rho * g * h
pv = 3200
T1 = []
T2 = []
v_range = np.linspace(5, 40, 20)


for v in v_range:
    sigma = (po - pv) / (0.5 * rho * v ** 2)
    X1[1] = 0.8
    X1[2] = 1.4
    X1[3] = sigma
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    T = (KT_1 * rho * (3000) ** 2 * (0.4) ** 4) / 3600
    T1.append(T)

# plot the second curve with orange dotted line
plt.plot(v_range, T1, 'o:', color='orange', label='P/D = 1.4, RPM = 3000')

# find intersection points
idx = np.where(np.diff(np.sign(np.array(T1) - spline(v_range))))[0]
print(idx)
# plot intersection points
plt.plot(v_range[idx[0]], T1[idx[0]], 'ro')

v1_range = np.linspace(5, 30, 25)


for v in v1_range:
    sigma = (po - pv) / (0.5 * rho * v ** 2)
    X1[1] = 0.8
    X1[2] = 1.2
    X1[3] = sigma
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    T = (KT_1 * rho * (2000) ** 2 * (0.4) ** 4) / 3600
    T2.append(T)

# plot the second curve with orange dotted line
plt.plot(v1_range, T2, 'o:', color='darkorange', label='P/D = 1.2, RPM = 2000')

# find intersection points
idx1 = np.where(np.diff(np.sign(np.array(T2) - spline(v1_range))))[0]
print(idx)
# plot intersection points
plt.plot(v1_range[idx1[0]], T2[idx1[0]], 'ro')

v2_range = np.linspace(5, 40, 30)

T3 = []
for v in v2_range:
    sigma = (po - pv) / (0.5 * rho * v ** 2)
    X1[1] = 0.8
    X1[2] = 1.6
    X1[3] = sigma
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    T = (KT_1 * rho * (3500) ** 2 * (0.4) ** 4) / 3600
    T3.append(T)

# plot the second curve with orange dotted line
plt.plot(v2_range, T3, 'o:', color='darkblue', label='P/D = 1.6, RPM = 3250')

# find intersection points
idx2 = np.where(np.diff(np.sign(np.array(T3) - spline(v2_range))))[0]
print(idx)
# plot intersection points
plt.plot(v2_range[idx2[0]], T3[idx2[0]], 'ro')


plt.grid(True)
plt.legend()

plt.show()
# Out:
# [11]
# [11]
# [11]

# %%
import matplotlib.pyplot as plt

# Define the RPM and Power data
rpm = [200, 200, 1000, 2000, 3000, 3250, 3500, 3500]
power = [0, 20, 100, 200, 300, 300, 300, 0]

# Create the plot
plt.plot(rpm, power, marker='o', linestyle='-', color='b')

# Set the plot title and labels
plt.title('Power Delivery of Engine')
plt.xlabel('RPM (propeller)')
plt.ylabel('Power (kW)')

# Set the x-axis range and tick labels
plt.xticks([0, 1000, 2000, 3000, 3500])
plt.xlim(0, 3750)

# Set the y-axis range and tick labels
plt.yticks([0, 100, 200, 300,400,450])
plt.ylim(0, 450)
v = 26
sigma = (po - pv) / (0.5 * rho * v ** 2)
X1[1] = 0.8
X1[2] = 1.4
X1[3] = sigma
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
T = (KT_1 * rho * (3000) ** 2 * (0.4) ** 4) / 3600
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
P = (KQ_1 * rho * (3000)**3 * (0.4)**5*2*np.pi)/216000
print(P)
plt.plot(3000,P/1000,'ro',label='P/D = 1.4, RPM = 3000',color = 'orange')
v = 10
sigma = (po - pv) / (0.5 * rho * v ** 2)
X1[1] = 0.8
X1[2] = 1.2
X1[3] = sigma
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
T = (KT_1 * rho * (2000) ** 2 * (0.4) ** 4) / 3600
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
P = (KQ_1 * rho * (2000)**3 * (0.4)**5*2*np.pi)/216000
print(P)
plt.plot(2000,P/1000,'ro',label='P/D = 1.2, RPM = 2000',  color = 'darkorange')
v = 32
sigma = (po - pv) / (0.5 * rho * v ** 2)
X1[1] = 0.8
X1[2] = 1.6
X1[3] = sigma
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
T = (KT_1 * rho * (3250) ** 2 * (0.4) ** 4) / 3600
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
P = (KQ_1 * rho * (3250)**3 * (0.4)**5*2*np.pi)/216000
print(P)
plt.plot(3250, P/1000,'ro',label='P/D = 1.6, RPM = 3250',color = 'darkblue')
plt.grid(True)
plt.legend()
# Display the plot
plt.show()
# Out:
# 296783.5069238606
# 122083.39088688535
# 423280.28014758084
# C:\Users\stanleygabriel97\AppData\Local\Temp\ipykernel_2020\266160877.py:32: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(3000,P/1000,'ro',label='P/D = 1.4, RPM = 3000',color = 'orange')
# C:\Users\stanleygabriel97\AppData\Local\Temp\ipykernel_2020\266160877.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(2000,P/1000,'ro',label='P/D = 1.2, RPM = 2000',  color = 'darkorange')
# C:\Users\stanleygabriel97\AppData\Local\Temp\ipykernel_2020\266160877.py:54: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(3250, P/1000,'ro',label='P/D = 1.6, RPM = 3250',color = 'darkblue')

# %%
import cupy as cp
import time

start_time = time.time()
possibleV = cp.array([])

import cupy as cp

possibleV = cp.array([])

for v in cp.linspace(20, 30, 101):
    for rpm in cp.linspace(3000, 3500, 501):
        for pod in cp.linspace(1.05, 2.08, 104):
            for D in cp.linspace(0.4, 0.5, 51):
                J = v * 60 / (rpm * D)
                patm = 101300
                rho = 1025
                g = 9.81
                h = 1
                po = patm + rho * g * h
                pv = 3200
                sigma = (po - pv) / (0.5 * rho * v ** 2)
                X1[1] = 0.8
                X1[2] = pod
                X1[3] = sigma
                X1[0] = J
                R = spline(v.get())  # You might need to implement your own GPU version of this
                KT_1 = calculate_Y2_cupy(C2, O2, a2, h2, D2, X1, E2, G2, L2)  # You might need to implement your own GPU version of this
                KQ_1 = calculate_Y1_cupy(C1, O1, a1, h1, D1, X1, E1, G1, L1)  # You might need to implement your own GPU version of this
                T = (KT_1 * rho * rpm ** 2 * D ** 4) / 3600
                P = (KQ_1 * rho * rpm ** 3 * D ** 5 * 2 * np.pi) / 216000
                if R < T + 0.1 * R and R > T - 0.1 * R:
                    if P < Pmax:
                        possibleV = cp.append(possibleV, v)

end_time = time.time()

elapsed_time = end_time - start_time
print(f"Time taken to run the code: {elapsed_time} seconds")
# Out:
# Time taken to run the code: 5656.950903892517 seconds

# %%
X1 = np.zeros(4)
X2 = np.zeros(4)
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
objective_values = [] 
objetive_indices = []
# Define the bounds for J
J_bounds = (0.5, 2.25)

# Define the bounds for n
n_bounds = (50,3500)

# Define the bounds for D
D_bounds = (0.4, 0.5)

# Define the bounds for P/D
pod_bounds = (1.05,2.08)

# Given points for resistance curve
vboat = np.array([0, 2.5, 5, 7.5, 10, 15, 20, 30, 40])
resistance = np.array([0, 475, 1900, 4275, 6900, 6000, 5740, 10125, 24000])
A = [0.54,-0.054,-0.54]
B = [0.08,-0.02,-0.06]
rho = 1025
Pmax = 300000
# Cubic spline interpolation of the resistance curve
spline = interpolate.CubicSpline(vboat, resistance)
def record_objective_value(xk, convergence=None):
    objective_values.append(objective(xk))
# Define the new objective function to be maximized
def objective(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1[1] = 0.8
    X1[2] = pod
    X1[3] = sigma
    X1[0] = J 
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T -0.1*R:
        return 1e12  # Return a large value for excessive thrust
    if n>=3000:
        if P > Pmax:
            return 1e12  # Return a large negative value for excessive power
        return -V  # Negative sign to maximize speed
    if n<3000:
        if P> 100*n:
            return 1e12
        return -V
objective_values =  []
objective_values1 =  []
def record_objective_value(xk, convergence=None):
    objective_values.append(-objective(xk))
    objective_values1.append(xk)
strategy = 'best1bin'    
# Find the optimal values of J, n, and D
result = differential_evolution(objective, bounds=[J_bounds, n_bounds, D_bounds, pod_bounds],maxiter =1000,strategy= strategy,callback = record_objective_value)
print(result)
patm=101300 
rho=1025 
g=9.81 
h=1
po=patm+rho*g*h
pv = 3200 
sigma1= (po-pv)/(0.5*rho*(-result.fun)**2)
X2[1] = 0.8
X2[2] = result.x[3]
X2[3] = sigma1
X2[0] = result.x[0]
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
T = (KT_1 * rho * result.x[1]**2 * result.x[2]**4)/3600
P = (KQ_1 * rho * result.x[1]**3 * result.x[2]**5*2*np.pi)/216000
result_value = -result.fun
plt.plot(objective_values)

plt.xlabel('Generation')
plt.ylabel('Objective Function Value')
plt.title('Boat Speed Optimization')

# Add the label at the bottom right corner
result_label = 'Top Speed: ' + "{:.3f}".format(result_value) + ' m/s'
diameter_label = 'Diameter: {:.4f} m'.format(result.x[2])
rpm_label = 'RPM: {:.1f}'.format(result.x[1])
j_label = 'J Value: {:.3f}'.format(result.x[0])
pitch_label = 'P/D: {:.3f}'.format(result.x[3])
power_label = 'Power: {:.3f} KW'.format(P/1000)

box_props = dict(boxstyle='round,pad=0.4', facecolor='white', edgecolor='black')

plt.text(0.8, 0.15, result_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.25, power_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.35, diameter_label, color='green', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.45, rpm_label, color='red', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)
plt.text(0.8, 0.55, pitch_label, color='purple', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.65, j_label, color='darkorange', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.8, strategy+': '+str(result.nfev), color='black', transform=plt.gca().transAxes,
         fontsize=10, weight = 'bold', ha='right', va='top', bbox=box_props)

plt.show()
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: -27.710770524790327
#        x: [ 1.348e+00  3.060e+03  4.032e-01  1.525e+00]
#      nit: 97
#     nfev: 5985

# %%
X1 = np.zeros(4)
X2 = np.zeros(4)
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
objective_values = [] 
objetive_indices = []
# Define the bounds for J
J_bounds = (0.5, 2.25)

# Define the bounds for n
n_bounds = (50,3500)

# Define the bounds for D
D_bounds = (0.4, 0.5)

# Define the bounds for P/D
pod_bounds = (1.05,2.08)

# Given points for resistance curve
vboat = np.array([0, 2.5, 5, 7.5, 10, 15, 20, 30, 40])
resistance = np.array([0, 475, 1900, 4275, 6900, 6000, 5740, 10125, 24000])
A = [0.54,-0.054,-0.54]
B = [0.08,-0.02,-0.06]
rho = 1025
Pmax = 300000
# Cubic spline interpolation of the resistance curve
spline = interpolate.CubicSpline(vboat, resistance)
def record_objective_value(xk, convergence=None):
    objective_values.append(objective(xk))
# Define the new objective function to be maximized
def objective(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1[1] = 0.8
    X1[2] = pod
    X1[3] = sigma
    X1[0] = J 
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T -0.1*R:
        return 1e12  # Return a large value for excessive thrust
    if n>=3000:
        if P > Pmax:
            return 1e12  # Return a large negative value for excessive power
        return -V  # Negative sign to maximize speed
    if n<3000:
        if P> 100*n:
            return 1e12
        return -V
objective_values =  []
objective_values1 =  []
def record_objective_value(xk, convergence=None):
    objective_values.append(-objective(xk))
    objective_values1.append(xk)
strategy = 'best1exp'    
# Find the optimal values of J, n, and D
result = differential_evolution(objective, bounds=[J_bounds, n_bounds, D_bounds, pod_bounds],maxiter =1000,strategy= strategy,callback = record_objective_value)
print(result)
patm=101300 
rho=1025 
g=9.81 
h=1
po=patm+rho*g*h
pv = 3200 
sigma1= (po-pv)/(0.5*rho*(-result.fun)**2)
X2[1] = 0.8
X2[2] = result.x[3]
X2[3] = sigma1
X2[0] = result.x[0]
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
T = (KT_1 * rho * result.x[1]**2 * result.x[2]**4)/3600
P = (KQ_1 * rho * result.x[1]**3 * result.x[2]**5*2*np.pi)/216000
result_value = -result.fun
plt.plot(objective_values)

plt.xlabel('Generation')
plt.ylabel('Objective Function Value')
plt.title('Boat Speed Optimization')

# Add the label at the bottom right corner
result_label = 'Top Speed: ' + "{:.3f}".format(result_value) + ' m/s'
diameter_label = 'Diameter: {:.4f} m'.format(result.x[2])
rpm_label = 'RPM: {:.1f}'.format(result.x[1])
j_label = 'J Value: {:.3f}'.format(result.x[0])
pitch_label = 'P/D: {:.3f}'.format(result.x[3])
power_label = 'Power: {:.3f} KW'.format(P/1000)

box_props = dict(boxstyle='round,pad=0.4', facecolor='white', edgecolor='black')

plt.text(0.8, 0.15, result_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.25, power_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.35, diameter_label, color='green', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.45, rpm_label, color='red', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)
plt.text(0.8, 0.55, pitch_label, color='purple', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.65, j_label, color='darkorange', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.8, strategy+': '+str(result.nfev), color='black', transform=plt.gca().transAxes,
         fontsize=10, weight = 'bold', ha='right', va='top', bbox=box_props)

plt.show()
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: -27.771402346633597
#        x: [ 1.379e+00  3.014e+03  4.009e-01  1.568e+00]
#      nit: 144
#     nfev: 8805

# %%
X1 = np.zeros(4)
X2 = np.zeros(4)
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
objective_values = [] 
objetive_indices = []
# Define the bounds for J
J_bounds = (0.5, 2.25)

# Define the bounds for n
n_bounds = (50,3500)

# Define the bounds for D
D_bounds = (0.4, 0.5)

# Define the bounds for P/D
pod_bounds = (1.05,2.08)

# Given points for resistance curve
vboat = np.array([0, 2.5, 5, 7.5, 10, 15, 20, 30, 40])
resistance = np.array([0, 475, 1900, 4275, 6900, 6000, 5740, 10125, 24000])
A = [0.54,-0.054,-0.54]
B = [0.08,-0.02,-0.06]
rho = 1025
Pmax = 300000
# Cubic spline interpolation of the resistance curve
spline = interpolate.CubicSpline(vboat, resistance)
def record_objective_value(xk, convergence=None):
    objective_values.append(objective(xk))
# Define the new objective function to be maximized
def objective(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1[1] = 0.8
    X1[2] = pod
    X1[3] = sigma
    X1[0] = J 
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T -0.1*R:
        return 1e12  # Return a large value for excessive thrust
    if n>=3000:
        if P > Pmax:
            return 1e12  # Return a large negative value for excessive power
        return -V  # Negative sign to maximize speed
    if n<3000:
        if P> 100*n:
            return 1e12
        return -V
objective_values =  []
objective_values1 =  []
def record_objective_value(xk, convergence=None):
    objective_values.append(-objective(xk))
    objective_values1.append(xk)
strategy = 'rand1exp'    
# Find the optimal values of J, n, and D
result = differential_evolution(objective, bounds=[J_bounds, n_bounds, D_bounds, pod_bounds],maxiter =1000,strategy= strategy,callback = record_objective_value)
print(result)
patm=101300 
rho=1025 
g=9.81 
h=1
po=patm+rho*g*h
pv = 3200 
sigma1= (po-pv)/(0.5*rho*(-result.fun)**2)
X2[1] = 0.8
X2[2] = result.x[3]
X2[3] = sigma1
X2[0] = result.x[0]
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
T = (KT_1 * rho * result.x[1]**2 * result.x[2]**4)/3600
P = (KQ_1 * rho * result.x[1]**3 * result.x[2]**5*2*np.pi)/216000
result_value = -result.fun
plt.plot(objective_values)

plt.xlabel('Generation')
plt.ylabel('Objective Function Value')
plt.title('Boat Speed Optimization')

# Add the label at the bottom right corner
result_label = 'Top Speed: ' + "{:.3f}".format(result_value) + ' m/s'
diameter_label = 'Diameter: {:.4f} m'.format(result.x[2])
rpm_label = 'RPM: {:.1f}'.format(result.x[1])
j_label = 'J Value: {:.3f}'.format(result.x[0])
pitch_label = 'P/D: {:.3f}'.format(result.x[3])
power_label = 'Power: {:.3f} KW'.format(P/1000)

box_props = dict(boxstyle='round,pad=0.4', facecolor='white', edgecolor='black')

plt.text(0.8, 0.15, result_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.25, power_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.35, diameter_label, color='green', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.45, rpm_label, color='red', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)
plt.text(0.8, 0.55, pitch_label, color='purple', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.65, j_label, color='darkorange', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.8, strategy+': '+str(result.nfev), color='black', transform=plt.gca().transAxes,
         fontsize=10, weight = 'bold', ha='right', va='top', bbox=box_props)

plt.show()
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: -27.613558170999557
#        x: [ 1.345e+00  3.009e+03  4.094e-01  1.517e+00]
#      nit: 190
#     nfev: 11565

# %%
X1 = np.zeros(4)
X2 = np.zeros(4)
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
objective_values = [] 
objetive_indices = []
# Define the bounds for J
J_bounds = (0.5, 2.25)

# Define the bounds for n
n_bounds = (50,3500)

# Define the bounds for D
D_bounds = (0.4, 0.5)

# Define the bounds for P/D
pod_bounds = (1.05,2.08)

# Given points for resistance curve
vboat = np.array([0, 2.5, 5, 7.5, 10, 15, 20, 30, 40])
resistance = np.array([0, 475, 1900, 4275, 6900, 6000, 5740, 10125, 24000])
A = [0.54,-0.054,-0.54]
B = [0.08,-0.02,-0.06]
rho = 1025
Pmax = 300000
# Cubic spline interpolation of the resistance curve
spline = interpolate.CubicSpline(vboat, resistance)
def record_objective_value(xk, convergence=None):
    objective_values.append(objective(xk))
# Define the new objective function to be maximized
def objective(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1[1] = 0.8
    X1[2] = pod
    X1[3] = sigma
    X1[0] = J 
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T -0.1*R:
        return 1e12  # Return a large value for excessive thrust
    if n>=3000:
        if P > Pmax:
            return 1e12  # Return a large negative value for excessive power
        return -V  # Negative sign to maximize speed
    if n<3000:
        if P> 100*n:
            return 1e12
        return -V
objective_values =  []
objective_values1 =  []
def record_objective_value(xk, convergence=None):
    objective_values.append(-objective(xk))
    objective_values1.append(xk)
strategy = 'currenttobest1exp'    
# Find the optimal values of J, n, and D
result = differential_evolution(objective, bounds=[J_bounds, n_bounds, D_bounds, pod_bounds],maxiter =1000,strategy= strategy,callback = record_objective_value)
print(result)
patm=101300 
rho=1025 
g=9.81 
h=1
po=patm+rho*g*h
pv = 3200 
sigma1= (po-pv)/(0.5*rho*(-result.fun)**2)
X2[1] = 0.8
X2[2] = result.x[3]
X2[3] = sigma1
X2[0] = result.x[0]
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
T = (KT_1 * rho * result.x[1]**2 * result.x[2]**4)/3600
P = (KQ_1 * rho * result.x[1]**3 * result.x[2]**5*2*np.pi)/216000
result_value = -result.fun
plt.plot(objective_values)

plt.xlabel('Generation')
plt.ylabel('Objective Function Value')
plt.title('Boat Speed Optimization')

# Add the label at the bottom right corner
result_label = 'Top Speed: ' + "{:.3f}".format(result_value) + ' m/s'
diameter_label = 'Diameter: {:.4f} m'.format(result.x[2])
rpm_label = 'RPM: {:.1f}'.format(result.x[1])
j_label = 'J Value: {:.3f}'.format(result.x[0])
pitch_label = 'P/D: {:.3f}'.format(result.x[3])
power_label = 'Power: {:.3f} KW'.format(P/1000)

box_props = dict(boxstyle='round,pad=0.4', facecolor='white', edgecolor='black')

plt.text(0.8, 0.15, result_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.25, power_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.35, diameter_label, color='green', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.45, rpm_label, color='red', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)
plt.text(0.8, 0.55, pitch_label, color='purple', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.65, j_label, color='darkorange', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.8, strategy+': '+str(result.nfev), color='black', transform=plt.gca().transAxes,
         fontsize=10, weight = 'bold', ha='right', va='top', bbox=box_props)

plt.show()
# Out:
#  message: Maximum number of iterations has been exceeded.
#  success: False
#      fun: -27.787521892668178
#        x: [ 1.389e+00  3.000e+03  4.000e-01  1.582e+00]
#      nit: 1000
#     nfev: 60165

# %%
X1 = np.zeros(4)
X2 = np.zeros(4)
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import differential_evolution
objective_values = [] 
objetive_indices = []
# Define the bounds for J
J_bounds = (0.5, 2.25)

# Define the bounds for n
n_bounds = (50,3500)

# Define the bounds for D
D_bounds = (0.4, 0.5)

# Define the bounds for P/D
pod_bounds = (1.05,2.08)

# Given points for resistance curve
vboat = np.array([0, 2.5, 5, 7.5, 10, 15, 20, 30, 40])
resistance = np.array([0, 475, 1900, 4275, 6900, 6000, 5740, 10125, 24000])
A = [0.54,-0.054,-0.54]
B = [0.08,-0.02,-0.06]
rho = 1025
Pmax = 300000
# Cubic spline interpolation of the resistance curve
spline = interpolate.CubicSpline(vboat, resistance)
def record_objective_value(xk, convergence=None):
    objective_values.append(objective(xk))
# Define the new objective function to be maximized
def objective(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1[1] = 0.8
    X1[2] = pod
    X1[3] = sigma
    X1[0] = J 
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T -0.1*R:
        return 1e12  # Return a large value for excessive thrust
    if n>=3000:
        if P > Pmax:
            return 1e12  # Return a large negative value for excessive power
        return -V  # Negative sign to maximize speed
    if n<3000:
        if P> 100*n:
            return 1e12
        return -V
objective_values =  []
objective_values1 =  []
def record_objective_value(xk, convergence=None):
    objective_values.append(-objective(xk))
    objective_values1.append(xk)
strategy = 'rand2exp'    
# Find the optimal values of J, n, and D
result = differential_evolution(objective, bounds=[J_bounds, n_bounds, D_bounds, pod_bounds],maxiter =1000,strategy= strategy,callback = record_objective_value)
print(result)
patm=101300 
rho=1025 
g=9.81 
h=1
po=patm+rho*g*h
pv = 3200 
sigma1= (po-pv)/(0.5*rho*(-result.fun)**2)
X2[1] = 0.8
X2[2] = result.x[3]
X2[3] = sigma1
X2[0] = result.x[0]
KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
T = (KT_1 * rho * result.x[1]**2 * result.x[2]**4)/3600
P = (KQ_1 * rho * result.x[1]**3 * result.x[2]**5*2*np.pi)/216000
result_value = -result.fun
plt.plot(objective_values)

plt.xlabel('Generation')
plt.ylabel('Objective Function Value')
plt.title('Boat Speed Optimization')

# Add the label at the bottom right corner
result_label = 'Top Speed: ' + "{:.3f}".format(result_value) + ' m/s'
diameter_label = 'Diameter: {:.4f} m'.format(result.x[2])
rpm_label = 'RPM: {:.1f}'.format(result.x[1])
j_label = 'J Value: {:.3f}'.format(result.x[0])
pitch_label = 'P/D: {:.3f}'.format(result.x[3])
power_label = 'Power: {:.3f} KW'.format(P/1000)

box_props = dict(boxstyle='round,pad=0.4', facecolor='white', edgecolor='black')

plt.text(0.8, 0.15, result_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.25, power_label, color='blue', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.35, diameter_label, color='green', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.45, rpm_label, color='red', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)
plt.text(0.8, 0.55, pitch_label, color='purple', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.65, j_label, color='darkorange', transform=plt.gca().transAxes,
         fontsize=10, ha='right', va='top', bbox=box_props)

plt.text(0.8, 0.8, strategy+': '+str(result.nfev), color='black', transform=plt.gca().transAxes,
         fontsize=10, weight = 'bold', ha='right', va='top', bbox=box_props)

plt.show()
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: -27.60497730760381
#        x: [ 1.338e+00  3.020e+03  4.098e-01  1.507e+00]
#      nit: 381
#     nfev: 23025

# %%
import numpy as np
import matplotlib.pyplot as plt

def differential_evolution(func, bounds, popsize=40, its=100):
    num_params = len(bounds)
    pop = np.random.rand(popsize, num_params)
    min_b, max_b = np.asarray(bounds).T
    diff = np.fabs(min_b - max_b)
    population = min_b + pop * diff
    fitness = np.asarray([func(ind) for ind in population])
    best_idx = np.argmin(fitness)
    best = population[best_idx]
    pop_history = []  # Create a list to store the population history
    pop_1 = []
    for i in range(its):
        for j in range(popsize):
            idxs = [idx for idx in range(popsize) if idx != j]
            a, b, c = population[np.random.choice(idxs, 3, replace = False)]
            mutant = np.clip(a + 0.5 * (b - c), min_b, max_b)
            cross_points = np.random.rand(num_params) < 0.9
            if not np.any(cross_points):
                cross_points[np.random.randint(0, num_params)] = True
            trial = np.where(cross_points, mutant, population[j])
            trial_fitness = func(trial)
            if trial_fitness < fitness[j]:
                fitness[j] = trial_fitness
                population[j] = trial
                if trial_fitness < fitness[best_idx]:
                    best_idx = j
                    best = trial
        if i % 4 == 0:
            pop_1.append(np.array(population))
            pop_history.append(np.prod(population[:, :3], axis=1)/60)  # Store the product of each individual in the population
            
    return best, fitness[best_idx], pop_history,pop_1  # Also return the population history

bounds = [J_bounds, n_bounds, D_bounds, pod_bounds]
result, fitness, pop_history,pop1 = differential_evolution(objective, bounds)  # Get the population history from the function

# %%
# Create scatter plot of population history
for i, pop in enumerate(pop_history):
    for j in pop1[i]:
        if i < len(pop_history) * 0.33:  # First third of the iterations
            if objective(j)>0:
                color = 'grey'
            else:
                color = 'orange'
        elif i < len(pop_history) * 0.66:  # Second third of the iterations
            if objective(j)>0:
                color = 'grey'
            else:
                color = 'darkorange'
        else:  # Last third of the iterations
            if objective(j)>0:
                color = 'grey'
            else:
                color = 'red'
        plt.scatter(i*4, j[0]*j[1]*j[2]/60, c=color, alpha=0.3)  # Multiply i by 5 to get the correct iteration number
    
plt.title('Population History')
plt.xlabel('Iteration')
plt.ylabel('Advance Velocity')
plt.show()

# %%
import pyswarms as ps
n_bounds = (3000,3500)
def objective_1(X):
    n_particles = X.shape[0]  # number of particles
    output = np.zeros(n_particles)  # Initialize array for storing outputs

    for i in range(n_particles):
        J, n, D, pod = X[i]
        V = J * n * D/60
        patm=101300 
        rho=1025 
        g=9.81 
        h=1
        po=patm+rho*g*h
        pv =3200 
        sigma= (po-pv)/(0.5*rho*V**2)
        X1[1] = 0.8
        X1[2] = pod
        X1[3] = sigma
        X1[0] = J 
        KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
        KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
        T = (KT_1 * rho * n**2 * D**4)/3600
        P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
        R = spline(V) 
        if R > T+0.1*R or R < T -0.1*R:
            output[i] = 1e12  # Return a large value for excessive thrust
        elif P > Pmax:
            output[i] = 1e12  # Return a large negative value for excessive power
        else:
            output[i] = -V  # Negative sign to maximize speed

    return output

lb = [J_bounds[0], n_bounds[0], D_bounds[0], pod_bounds[0]]
ub = [J_bounds[1], n_bounds[1], D_bounds[1], pod_bounds[1]]

options = {'c1': 0.5, 'c2': 0.3, 'w':0.9}

optimizer = ps.single.GlobalBestPSO(n_particles=20, dimensions=4, options=options, bounds=(lb, ub))

cost, pos = optimizer.optimize(objective_1, iters=300)
# Out:
# 2023-07-16 22:42:56,268 - pyswarms.single.global_best - INFO - Optimize for 300 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|████████████████████████████████████████████████████████████|300/300, best_cost=-27.4
# 2023-07-16 22:42:57,343 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -27.409939650169335, best pos: [1.27419753e+00 3.17301655e+03 4.06771235e-01 1.43036011e+00]

# %%
# Determine threshold
threshold = 1e6  # set a threshold value based on your requirements

# Filter values
filtered_values = [-i for i in optimizer.cost_history if i < threshold]

plt.figure(figsize=(10,8))
plt.plot(filtered_values)
plt.title('Particle Swarm Optimization')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value (Top Speed in m/s)')
plt.grid(True)
plt.show()

# %%
from platypus import NSGAII, Problem, Real

problem = Problem(4, 1)
problem.types[:] = [Real(J_bounds[0], J_bounds[1]), Real(n_bounds[0], n_bounds[1]), 
                    Real(D_bounds[0], D_bounds[1]), Real(pod_bounds[0], pod_bounds[1])]
problem.function = objective

algorithm = NSGAII(problem)
algorithm.run(10000)
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Create a list to hold the objective function values
objectives = [s.objectives[0] for s in algorithm.result]

# Define a function that formats the y-axis values
def one_decimal(x, pos):
    return '%.3f' % x

# Create a formatter
formatter = FuncFormatter(one_decimal)

# Create the plot
fig, ax = plt.subplots(figsize=(10,5))
ax.yaxis.set_major_formatter(formatter)
ax.plot(range(len(objectives)), objectives)
ax.set_title('Objective Function Values')
ax.set_xlabel('Iteration')
ax.set_ylabel('Objective Function Value')
ax.grid(True)

plt.show()
# Out:
# 2023-07-16 22:55:41,637 - Platypus - INFO - NSGAII starting
# 2023-07-16 22:55:45,231 - Platypus - INFO - NSGAII finished; Total NFE: 10000, Elapsed Time: 0:00:03.594055

# %%
algorithm.result[0]
# Out:
# Solution[1.2843721825351675,3125.139992583889,0.4104993231313436,1.4402993039093692|-27.46132970872101|0]

# %%
def objective_2(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1[1] = 0.8
    X1[2] = pod
    X1[3] = sigma
    X1[0] = J 
    KT_1 = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)
    KQ_1 = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T -0.1*R:
        return (1e12,)  # Return a large value for excessive thrust
    if P > Pmax:
        return (1e12,)  # Return a large negative value for excessive power
    return (-V,)  # Negative sign to maximize speed

# %%
from deap import base, creator, tools
import random
from deap import algorithms
import numpy as np

def uniform(a, b):
    return random.uniform(a, b)

creator.create("FitnessMax", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()
toolbox.register("attr_J", uniform, J_bounds[0], J_bounds[1])
toolbox.register("attr_n", uniform, n_bounds[0], n_bounds[1])
toolbox.register("attr_D", uniform, D_bounds[0], D_bounds[1])
toolbox.register("attr_pod", uniform, pod_bounds[0], pod_bounds[1])

toolbox.register("individual", tools.initCycle, creator.Individual,
                 (toolbox.attr_J, toolbox.attr_n, toolbox.attr_D, toolbox.attr_pod), n=1)

toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("mate", tools.cxTwoPoint)
def mutate_individual(individual):
    # The mutation boundaries for each attribute
    bounds = [J_bounds, n_bounds, D_bounds, pod_bounds]
    
    # Apply the mutation operator to each attribute of the individual
    for i, (low, up) in enumerate(bounds):
        if random.random() < 0.1:  # The mutation probability for each attribute
            # Call the mutation operator
            delta1 = (individual[i] - low) / (up - low)
            delta2 = (up - individual[i]) / (up - low)
            rand = random.random()
            mut_pow = 1.0 / (1.0 + 1.0)
            if rand < 0.5:
                xy = 1.0 - delta1
                val = 2.0*rand + (1.0 - 2.0*rand) * (xy**(1.0 + 1.0))
                delta_q = val**mut_pow - 1.0
            else:
                xy = 1.0 - delta2
                val = 2.0 * (1.0 - rand) + 2.0 * (rand - 0.5) * (xy**(1.0 + 1.0))
                delta_q = 1.0 - val**mut_pow
            individual[i] += delta_q * (up - low)
            individual[i] = min(max(individual[i], low), up)  # Make sure the new value is within the mutation boundaries
    return individual,

# Register the custom mutation function
toolbox.register("mutate", mutate_individual)

toolbox.register("mutate", mutate_individual)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", objective_2)

def main():
    pop = toolbox.population(n=300)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("min", np.min)
    stats.register("max", np.max)

    pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=400, 
                                   stats=stats, halloffame=hof, verbose=True)

    return pop, log, hof

if __name__ == "__main__":
    main()
# Out:
# C:\Users\stanleygabriel97\AppData\Roaming\Python\Python311\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\stanleygabriel97\AppData\Roaming\Python\Python311\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# gen	nevals	avg  	min  	max
# 0  	300   	1e+12	1e+12	1e+12
# 1  	177   	9.96667e+11	-23.5027	1e+12
# 2  	170   	9.96667e+11	-23.481 	1e+12
# 3  	186   	9.96667e+11	-23.481 	1e+12
# 4  	189   	9.86667e+11	-23.481 	1e+12
# 5  	182   	9.83333e+11	-23.481 	1e+12
# 6  	183   	9.63333e+11	-23.481 	1e+12
# 7  	178   	9.5e+11    	-23.2918	1e+12
# 8  	166   	9.3e+11    	-23.2918	1e+12
# 9  	156   	8.5e+11    	-23.6309	1e+12
# 10 	188   	7.16667e+11	-23.8249	1e+12
# 11 	175   	4.96667e+11	-23.8249	1e+12
# 12 	188   	1.93333e+11	-23.8249	1e+12
# 13 	182   	1.33333e+11	-23.8249	1e+12
# 14 	186   	1.5e+11    	-23.8249	1e+12
# 15 	178   	1.56667e+11	-23.8249	1e+12
# 16 	158   	1.76667e+11	-23.8249	1e+12
# 17 	167   	1.53333e+11	-23.9596	1e+12
# 18 	171   	8.66667e+10	-23.8773	1e+12
# 19 	207   	8e+10      	-23.8773	1e+12
# 20 	185   	5.66667e+10	-23.8773	1e+12
# 21 	177   	6.66667e+10	-23.8773	1e+12
# 22 	189   	5e+10      	-24.2054	1e+12
# 23 	183   	5.66667e+10	-23.8773	1e+12
# 24 	176   	6.33333e+10	-23.8773	1e+12
# 25 	182   	5.33333e+10	-23.8773	1e+12
# 26 	176   	5.66667e+10	-24.0342	1e+12
# 27 	146   	4.33333e+10	-24.0342	1e+12
# 28 	164   	7e+10      	-24.0342	1e+12
# 29 	183   	6e+10      	-24.0342	1e+12
# 30 	176   	6.33333e+10	-24.128 	1e+12
# 31 	195   	3.33333e+10	-24.1383	1e+12
# 32 	195   	6.66667e+10	-24.162 	1e+12
# 33 	185   	7.66667e+10	-24.162 	1e+12
# 34 	193   	3.33333e+10	-24.162 	1e+12
# 35 	186   	3.66667e+10	-24.162 	1e+12
# 36 	190   	5e+10      	-24.162 	1e+12
# 37 	189   	5.33333e+10	-24.2417	1e+12
# 38 	169   	3.33333e+10	-24.2417	1e+12
# 39 	181   	6.33333e+10	-24.2417	1e+12
# 40 	191   	6.66667e+10	-24.2417	1e+12
# 41 	187   	5.33333e+10	-24.2833	1e+12
# 42 	202   	8.33333e+10	-24.2833	1e+12
# 43 	178   	6e+10      	-24.2833	1e+12
# 44 	174   	7e+10      	-24.2833	1e+12
# 45 	180   	5.33333e+10	-24.2833	1e+12
# 46 	202   	5e+10      	-24.2833	1e+12
# 47 	179   	6.66667e+10	-24.2933	1e+12
# 48 	173   	7.66667e+10	-24.2933	1e+12
# 49 	179   	7e+10      	-24.2933	1e+12
# 50 	183   	7.33333e+10	-24.2933	1e+12
# 51 	168   	3.66667e+10	-24.2933	1e+12
# 52 	198   	7.66667e+10	-24.2933	1e+12
# 53 	194   	4.66667e+10	-24.2933	1e+12
# 54 	168   	6.66667e+10	-24.2933	1e+12
# 55 	187   	3.66667e+10	-24.2933	1e+12
# 56 	177   	6e+10      	-24.2933	1e+12
# 57 	189   	6.66667e+10	-24.2933	1e+12
# 58 	175   	5.33333e+10	-24.2933	1e+12
# 59 	171   	5.33333e+10	-24.2933	1e+12
# 60 	170   	4.33333e+10	-24.2933	1e+12
# 61 	175   	6.66667e+10	-24.2933	1e+12
# 62 	183   	6e+10      	-24.2933	1e+12
# 63 	194   	5.33333e+10	-24.2933	1e+12
# 64 	193   	9.33333e+10	-24.2933	1e+12
# 65 	171   	5.66667e+10	-24.2933	1e+12
# 66 	180   	6.66667e+10	-24.2933	1e+12
# 67 	189   	6.66667e+10	-24.2933	1e+12
# 68 	180   	6.33333e+10	-24.2933	1e+12
# 69 	171   	4.66667e+10	-24.2933	1e+12
# 70 	179   	6.33333e+10	-24.2933	1e+12
# 71 	153   	7.66667e+10	-24.2933	1e+12
# 72 	155   	6e+10      	-24.2933	1e+12
# 73 	185   	7e+10      	-24.2933	1e+12
# 74 	195   	6.33333e+10	-24.2933	1e+12
# 75 	182   	5e+10      	-24.2933	1e+12
# 76 	180   	7e+10      	-24.2933	1e+12
# 77 	194   	7.66667e+10	-24.2933	1e+12
# 78 	174   	3.33333e+10	-24.2933	1e+12
# 79 	192   	7e+10      	-24.2933	1e+12
# 80 	175   	6.66667e+10	-24.2933	1e+12
# 81 	188   	7e+10      	-24.2933	1e+12
# 82 	194   	4e+10      	-24.2933	1e+12
# 83 	185   	5e+10      	-24.2933	1e+12
# 84 	163   	3.33333e+10	-24.2933	1e+12
# 85 	167   	3.33333e+10	-24.2933	1e+12
# 86 	179   	6.33333e+10	-24.2933	1e+12
# 87 	175   	3.66667e+10	-24.2933	1e+12
# 88 	181   	5.33333e+10	-24.2933	1e+12
# 89 	185   	6e+10      	-24.2933	1e+12
# 90 	175   	3.66667e+10	-24.2933	1e+12
# 91 	179   	5.66667e+10	-24.2933	1e+12
# 92 	195   	6.33333e+10	-24.2933	1e+12
# 93 	162   	5e+10      	-24.2933	1e+12
# 94 	185   	5e+10      	-24.2933	1e+12
# 95 	191   	7e+10      	-24.2933	1e+12
# 96 	195   	6e+10      	-24.2933	1e+12
# 97 	187   	5.66667e+10	-24.2933	1e+12
# 98 	176   	5.33333e+10	-24.2933	1e+12
# 99 	184   	6.66667e+10	-24.2933	1e+12
# 100	192   	6e+10      	-24.2933	1e+12
# 101	191   	5.66667e+10	-24.2933	1e+12
# 102	199   	5.66667e+10	-24.2933	1e+12
# 103	179   	7.66667e+10	-24.2933	1e+12
# 104	178   	6e+10      	-24.2933	1e+12
# 105	182   	5.33333e+10	-24.2933	1e+12
# 106	185   	4.33333e+10	-24.2933	1e+12
# 107	180   	7.33333e+10	-24.2933	1e+12
# 108	177   	3.66667e+10	-24.2933	1e+12
# 109	182   	7.33333e+10	-24.2933	1e+12
# 110	178   	3.66667e+10	-24.2933	1e+12
# 111	163   	3e+10      	-24.2933	1e+12
# 112	171   	4.33333e+10	-24.2933	1e+12
# 113	193   	5.33333e+10	-24.2933	1e+12
# 114	172   	5.33333e+10	-24.2933	1e+12
# 115	180   	5e+10      	-24.2933	1e+12
# 116	196   	2.66667e+10	-24.2933	1e+12
# 117	196   	5.33333e+10	-24.2933	1e+12
# 118	177   	5e+10      	-24.2933	1e+12
# 119	179   	6e+10      	-24.2933	1e+12
# 120	172   	4.66667e+10	-24.2933	1e+12
# 121	189   	7e+10      	-24.2933	1e+12
# 122	167   	5.33333e+10	-24.2933	1e+12
# 123	169   	5.66667e+10	-24.2933	1e+12
# 124	183   	5e+10      	-24.2933	1e+12
# 125	183   	6.33333e+10	-24.2933	1e+12
# 126	183   	5.66667e+10	-24.2933	1e+12
# 127	172   	6.66667e+10	-24.2933	1e+12
# 128	162   	4.66667e+10	-24.2933	1e+12
# 129	191   	5.66667e+10	-24.2933	1e+12
# 130	173   	5e+10      	-24.2933	1e+12
# 131	181   	7e+10      	-24.2933	1e+12
# 132	178   	5.66667e+10	-24.2933	1e+12
# 133	177   	5.33333e+10	-24.2933	1e+12
# 134	188   	6.33333e+10	-24.2933	1e+12
# 135	177   	4.33333e+10	-24.2933	1e+12
# 136	175   	5.66667e+10	-24.2933	1e+12
# 137	172   	5e+10      	-24.2933	1e+12
# 138	189   	5.33333e+10	-24.2933	1e+12
# 139	175   	8e+10      	-24.2993	1e+12
# 140	184   	4e+10      	-24.2993	1e+12
# 141	191   	6e+10      	-24.2993	1e+12
# 142	175   	5.66667e+10	-24.2993	1e+12
# 143	182   	4.66667e+10	-24.2993	1e+12
# 144	186   	6.66667e+10	-24.2993	1e+12
# 145	160   	4.33333e+10	-24.2993	1e+12
# 146	185   	6.33333e+10	-24.2993	1e+12
# 147	193   	7.33333e+10	-24.2993	1e+12
# 148	189   	5.66667e+10	-24.2993	1e+12
# 149	182   	9.66667e+10	-24.2993	1e+12
# 150	181   	5.33333e+10	-24.2993	1e+12
# 151	181   	7.33333e+10	-24.2993	1e+12
# 152	183   	6e+10      	-24.2993	1e+12
# 153	188   	5e+10      	-24.2993	1e+12
# 154	174   	5.66667e+10	-24.2993	1e+12
# 155	203   	5.33333e+10	-24.2993	1e+12
# 156	186   	5.66667e+10	-24.2993	1e+12
# 157	207   	4.66667e+10	-24.2993	1e+12
# 158	177   	4.66667e+10	-24.2993	1e+12
# 159	161   	5e+10      	-24.2993	1e+12
# 160	160   	7.33333e+10	-24.2993	1e+12
# 161	177   	4.66667e+10	-24.2993	1e+12
# 162	178   	6e+10      	-24.2993	1e+12
# 163	192   	6.33333e+10	-24.2993	1e+12
# 164	182   	7.33333e+10	-24.2993	1e+12
# 165	178   	5e+10      	-24.2993	1e+12
# 166	176   	7e+10      	-24.2993	1e+12
# 167	192   	6.33333e+10	-24.2993	1e+12
# 168	184   	4.66667e+10	-24.2993	1e+12
# 169	182   	3.33333e+10	-24.2993	1e+12
# 170	173   	4e+10      	-24.2993	1e+12
# 171	182   	5.33333e+10	-24.2993	1e+12
# 172	179   	4.33333e+10	-24.2993	1e+12
# 173	192   	5.66667e+10	-24.2993	1e+12
# 174	179   	5.66667e+10	-24.2993	1e+12
# 175	191   	5.66667e+10	-24.2993	1e+12
# 176	167   	6.33333e+10	-24.2993	1e+12
# 177	195   	7e+10      	-24.2993	1e+12
# 178	191   	6.66667e+10	-24.2993	1e+12
# 179	189   	8.66667e+10	-24.2993	1e+12
# 180	193   	9e+10      	-24.2993	1e+12
# 181	179   	5e+10      	-24.2993	1e+12
# 182	186   	5.66667e+10	-24.2993	1e+12
# 183	172   	6.33333e+10	-24.2993	1e+12
# 184	192   	6e+10      	-24.2993	1e+12
# 185	199   	9e+10      	-24.2993	1e+12
# 186	186   	7.33333e+10	-24.2993	1e+12
# 187	180   	5.66667e+10	-24.2993	1e+12
# 188	192   	5.66667e+10	-24.2993	1e+12
# 189	178   	7.33333e+10	-24.2993	1e+12
# 190	186   	5.33333e+10	-24.2993	1e+12
# 191	175   	5.66667e+10	-24.2993	1e+12
# 192	175   	7e+10      	-24.2993	1e+12
# 193	171   	4.66667e+10	-24.2993	1e+12
# 194	180   	5.66667e+10	-24.2993	1e+12
# 195	164   	5.66667e+10	-24.2993	1e+12
# 196	186   	6e+10      	-24.2993	1e+12
# 197	178   	4e+10      	-24.2993	1e+12
# 198	195   	4.33333e+10	-24.2993	1e+12
# 199	181   	4e+10      	-24.2993	1e+12
# 200	166   	4e+10      	-24.2993	1e+12
# 201	196   	8.33333e+10	-24.2993	1e+12
# 202	168   	5e+10      	-24.2993	1e+12
# 203	177   	6.66667e+10	-24.2993	1e+12
# 204	193   	4.33333e+10	-24.2993	1e+12
# 205	157   	6e+10      	-24.2993	1e+12
# 206	186   	5.33333e+10	-24.2993	1e+12
# 207	166   	6.66667e+10	-24.2993	1e+12
# 208	183   	7.66667e+10	-24.2993	1e+12
# 209	177   	6e+10      	-24.2993	1e+12
# 210	180   	5.33333e+10	-24.2993	1e+12
# 211	173   	4.66667e+10	-24.2993	1e+12
# 212	160   	6.33333e+10	-24.2993	1e+12
# 213	171   	4e+10      	-24.2993	1e+12
# 214	185   	4.66667e+10	-24.2993	1e+12
# 215	175   	4.66667e+10	-24.2993	1e+12
# 216	156   	3e+10      	-24.2993	1e+12
# 217	167   	6.33333e+10	-24.2993	1e+12
# 218	191   	8.66667e+10	-24.2993	1e+12
# 219	193   	6e+10      	-24.2993	1e+12
# 220	191   	8.33333e+10	-24.2993	1e+12
# 221	178   	5.66667e+10	-24.2993	1e+12
# 222	194   	6e+10      	-24.2993	1e+12
# 223	182   	5e+10      	-24.2993	1e+12
# 224	184   	5.66667e+10	-24.2993	1e+12
# 225	171   	5e+10      	-24.2993	1e+12
# 226	180   	8e+10      	-24.2993	1e+12
# 227	203   	6e+10      	-24.2993	1e+12
# 228	182   	3.66667e+10	-24.2993	1e+12
# 229	189   	8.66667e+10	-24.2993	1e+12
# 230	185   	4e+10      	-24.2993	1e+12
# 231	176   	6.66667e+10	-24.2993	1e+12
# 232	172   	5.66667e+10	-24.2993	1e+12
# 233	176   	4.66667e+10	-24.2993	1e+12
# 234	193   	5e+10      	-24.2993	1e+12
# 235	175   	4.66667e+10	-24.2993	1e+12
# 236	192   	5.33333e+10	-24.2993	1e+12
# 237	176   	3.66667e+10	-24.2993	1e+12
# 238	191   	7e+10      	-24.2993	1e+12
# 239	182   	4.66667e+10	-24.2993	1e+12
# 240	193   	8.33333e+10	-24.2993	1e+12
# 241	163   	6.33333e+10	-24.2993	1e+12
# 242	172   	6.33333e+10	-24.2993	1e+12
# 243	180   	5.33333e+10	-24.2993	1e+12
# 244	194   	5.33333e+10	-24.2993	1e+12
# 245	164   	3.33333e+10	-24.2993	1e+12
# 246	186   	5.33333e+10	-24.2993	1e+12
# 247	168   	4e+10      	-24.2993	1e+12
# 248	169   	3.66667e+10	-24.2993	1e+12
# 249	173   	6e+10      	-24.2993	1e+12
# 250	186   	8e+10      	-24.2993	1e+12
# 251	179   	3.33333e+10	-24.2993	1e+12
# 252	199   	8.33333e+10	-24.2993	1e+12
# 253	175   	6.33333e+10	-24.2993	1e+12
# 254	190   	7e+10      	-24.2993	1e+12
# 255	187   	6e+10      	-24.2993	1e+12
# 256	181   	8.33333e+10	-24.2993	1e+12
# 257	186   	6.33333e+10	-24.2993	1e+12
# 258	159   	2.66667e+10	-24.2993	1e+12
# 259	176   	7.33333e+10	-24.2993	1e+12
# 260	187   	3.33333e+10	-24.2993	1e+12
# 261	176   	5e+10      	-24.2993	1e+12
# 262	193   	6.33333e+10	-24.2993	1e+12
# 263	190   	7.33333e+10	-24.2993	1e+12
# 264	197   	6e+10      	-24.2993	1e+12
# 265	179   	6.33333e+10	-24.2993	1e+12
# 266	189   	5.33333e+10	-24.2993	1e+12
# 267	198   	7e+10      	-24.2993	1e+12
# 268	182   	7.33333e+10	-24.2993	1e+12
# 269	174   	7e+10      	-24.2993	1e+12
# 270	168   	5.33333e+10	-24.2993	1e+12
# 271	189   	6e+10      	-24.2993	1e+12
# 272	189   	7e+10      	-24.2993	1e+12
# 273	190   	5e+10      	-24.2993	1e+12
# 274	172   	4.66667e+10	-24.2993	1e+12
# 275	172   	6e+10      	-24.2993	1e+12
# 276	206   	9e+10      	-24.2993	1e+12
# 277	158   	8e+10      	-24.2993	1e+12
# 278	174   	6e+10      	-24.2993	1e+12
# 279	167   	3.66667e+10	-24.2993	1e+12
# 280	173   	4.66667e+10	-24.2993	1e+12
# 281	176   	4.66667e+10	-24.2993	1e+12
# 282	173   	6.66667e+10	-24.2993	1e+12
# 283	167   	5e+10      	-24.2993	1e+12
# 284	162   	5e+10      	-24.2993	1e+12
# 285	198   	7e+10      	-24.2993	1e+12
# 286	183   	6e+10      	-24.2993	1e+12
# 287	166   	6.33333e+10	-24.2993	1e+12
# 288	180   	4.33333e+10	-24.2993	1e+12
# 289	195   	5.33333e+10	-24.2993	1e+12
# 290	155   	4e+10      	-24.2993	1e+12
# 291	182   	3.66667e+10	-24.2993	1e+12
# 292	182   	5.33333e+10	-24.2993	1e+12
# 293	184   	7.33333e+10	-24.2993	1e+12
# 294	185   	6e+10      	-24.2993	1e+12
# 295	179   	5e+10      	-24.2993	1e+12
# 296	192   	7.66667e+10	-24.2993	1e+12
# 297	180   	6e+10      	-24.2993	1e+12
# 298	188   	3.66667e+10	-24.2993	1e+12
# 299	185   	5e+10      	-24.2993	1e+12
# 300	193   	6.66667e+10	-24.2993	1e+12
# 301	165   	4e+10      	-24.2993	1e+12
# 302	186   	5.66667e+10	-24.2993	1e+12
# 303	182   	4.66667e+10	-24.2993	1e+12
# 304	169   	4e+10      	-24.2993	1e+12
# 305	185   	3.33333e+10	-24.2993	1e+12
# 306	171   	6e+10      	-24.2993	1e+12
# 307	189   	3.33333e+10	-24.2993	1e+12
# 308	194   	5.33333e+10	-24.2993	1e+12
# 309	202   	7e+10      	-24.2993	1e+12
# 310	185   	3.66667e+10	-24.2993	1e+12
# 311	184   	6e+10      	-24.2993	1e+12
# 312	173   	6.33333e+10	-24.2993	1e+12
# 313	177   	7.33333e+10	-24.2993	1e+12
# 314	181   	5.33333e+10	-24.2993	1e+12
# 315	190   	4.66667e+10	-24.2993	1e+12
# 316	194   	7e+10      	-24.2993	1e+12
# 317	183   	7.33333e+10	-24.2993	1e+12
# 318	168   	5e+10      	-24.2993	1e+12
# 319	196   	6.66667e+10	-24.2993	1e+12
# 320	191   	4.66667e+10	-24.2993	1e+12
# 321	160   	4.66667e+10	-24.2993	1e+12
# 322	168   	4.33333e+10	-24.2993	1e+12
# 323	175   	7e+10      	-24.2993	1e+12
# 324	169   	6e+10      	-24.2993	1e+12
# 325	164   	4e+10      	-24.2993	1e+12
# 326	196   	4.33333e+10	-24.2993	1e+12
# 327	184   	2.66667e+10	-24.2993	1e+12
# 328	181   	5e+10      	-24.2993	1e+12
# 329	207   	7.66667e+10	-24.2993	1e+12
# 330	185   	4.33333e+10	-24.2993	1e+12
# 331	166   	3.66667e+10	-24.2993	1e+12
# 332	186   	6.33333e+10	-24.2993	1e+12
# 333	173   	5.33333e+10	-24.2993	1e+12
# 334	171   	5.66667e+10	-24.2993	1e+12
# 335	192   	6e+10      	-24.2993	1e+12
# 336	191   	9e+10      	-24.2993	1e+12
# 337	159   	7.33333e+10	-24.2993	1e+12
# 338	189   	5.33333e+10	-24.2993	1e+12
# 339	198   	6.33333e+10	-24.2993	1e+12
# 340	174   	5.66667e+10	-24.2993	1e+12
# 341	183   	3.66667e+10	-24.2993	1e+12
# 342	175   	6.66667e+10	-24.2993	1e+12
# 343	193   	5e+10      	-24.2993	1e+12
# 344	173   	5.33333e+10	-24.2993	1e+12
# 345	176   	3.66667e+10	-24.2993	1e+12
# 346	173   	7.33333e+10	-24.2993	1e+12
# 347	213   	8.66667e+10	-24.2993	1e+12
# 348	176   	5.33333e+10	-24.2993	1e+12
# 349	177   	6.33333e+10	-24.2993	1e+12
# 350	157   	5e+10      	-24.2993	1e+12
# 351	159   	5e+10      	-24.2993	1e+12
# 352	178   	6e+10      	-24.2993	1e+12
# 353	173   	6.33333e+10	-24.2993	1e+12
# 354	180   	6.33333e+10	-24.2993	1e+12
# 355	199   	5e+10      	-24.2993	1e+12
# 356	171   	5.66667e+10	-24.2993	1e+12
# 357	186   	7.66667e+10	-24.2993	1e+12
# 358	192   	6e+10      	-24.2993	1e+12
# 359	194   	7e+10      	-24.2993	1e+12
# 360	183   	8.33333e+10	-24.2993	1e+12
# 361	160   	4.33333e+10	-24.2993	1e+12
# 362	195   	5e+10      	-24.2993	1e+12
# 363	162   	5e+10      	-24.2993	1e+12
# 364	173   	6.33333e+10	-24.2993	1e+12
# 365	166   	5e+10      	-24.2993	1e+12
# 366	181   	4e+10      	-24.2993	1e+12
# 367	170   	6.66667e+10	-24.2993	1e+12
# 368	193   	5.33333e+10	-24.2993	1e+12
# 369	194   	8e+10      	-24.2993	1e+12
# 370	181   	6.33333e+10	-24.2993	1e+12
# 371	158   	8e+10      	-24.2993	1e+12
# 372	174   	4e+10      	-24.2993	1e+12
# 373	187   	7.33333e+10	-24.2993	1e+12
# 374	191   	6.66667e+10	-24.2993	1e+12
# 375	175   	6.33333e+10	-24.2993	1e+12
# 376	173   	5.33333e+10	-24.2993	1e+12
# 377	173   	6e+10      	-24.2993	1e+12
# 378	188   	8e+10      	-24.2993	1e+12
# 379	180   	2.66667e+10	-24.2993	1e+12
# 380	187   	6e+10      	-24.2993	1e+12
# 381	187   	5.33333e+10	-24.2993	1e+12
# 382	198   	6e+10      	-24.2993	1e+12
# 383	203   	4e+10      	-24.2993	1e+12
# 384	176   	5.66667e+10	-24.2993	1e+12
# 385	186   	5.33333e+10	-24.2993	1e+12
# 386	175   	6e+10      	-24.2993	1e+12
# 387	189   	5.66667e+10	-24.2993	1e+12
# 388	198   	4.66667e+10	-24.2993	1e+12
# 389	175   	3.66667e+10	-24.2993	1e+12
# 390	177   	4.33333e+10	-24.2993	1e+12
# 391	188   	6.33333e+10	-24.2993	1e+12
# 392	184   	6.33333e+10	-24.2993	1e+12
# 393	178   	4.33333e+10	-24.2993	1e+12
# 394	172   	4e+10      	-24.2993	1e+12
# 395	175   	4.66667e+10	-24.2993	1e+12
# 396	176   	5.33333e+10	-24.2993	1e+12
# 397	176   	6.33333e+10	-24.2993	1e+12
# 398	166   	6.33333e+10	-24.2993	1e+12
# 399	198   	5.33333e+10	-24.2993	1e+12
# 400	174   	5.66667e+10	-24.2993	1e+12

# %%
import matplotlib.pyplot as plt

def main():
    pop = toolbox.population(n=300)
    hof = tools.HallOfFame(1)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("min", np.min)
    stats.register("max", np.max)

    # Create an empty list to store the best objective function values
    best_objectives = []

    # Run the evolutionary algorithm
    pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=200, 
                                   stats=stats, halloffame=hof, verbose=True)

    # Extract the best objective function values from the logbook
    best_objectives = [logbook["min"] for logbook in log]

    # Filter the objective function values less than 1e6
    filtered_objectives = [-obj for obj in best_objectives if obj < 1e6]
    
    # Plot the filtered objective function values with each iteration
    plt.figure(figsize=(10, 5))
    plt.plot(range(len(filtered_objectives)), filtered_objectives)
    plt.title('Genetic Algorithm')
    plt.xlabel('Iteration')
    plt.ylabel('Objective Function Value (Top Speed in m/s.)')
    plt.grid(True)
    plt.show()
    # Best individual
    best_ind = hof[0]

    # Extract parameters from the best individual
    J_best = best_ind[0]
    n_best = best_ind[1]
    D_best = best_ind[2]
    pod_best = best_ind[3]

    print(f"Best J: {J_best}")
    print(f"Best RPM (n): {n_best}")
    print(f"Best Diameter (D): {D_best}")
    print(f"Best Pod: {pod_best}")
    return pop, log, hof

if __name__ == "__main__":
    main()
# Out:
# gen	nevals	avg        	min     	max
# 0  	300   	9.96667e+11	-22.4136	1e+12
# 1  	167   	1e+12      	1e+12   	1e+12
# 2  	177   	9.93333e+11	-24.0035	1e+12
# 3  	177   	9.9e+11    	-24.0035	1e+12
# 4  	194   	9.86667e+11	-24.0035	1e+12
# 5  	187   	9.8e+11    	-24.6599	1e+12
# 6  	191   	9.7e+11    	-24.6599	1e+12
# 7  	192   	9.4e+11    	-25.3797	1e+12
# 8  	191   	9.06667e+11	-25.3797	1e+12
# 9  	193   	8.5e+11    	-25.6904	1e+12
# 10 	178   	6.83333e+11	-25.6904	1e+12
# 11 	182   	5.33333e+11	-25.7833	1e+12
# 12 	181   	2.46667e+11	-25.7833	1e+12
# 13 	168   	8.66667e+10	-26.0144	1e+12
# 14 	193   	9.66667e+10	-26.0144	1e+12
# 15 	177   	8e+10      	-26.1488	1e+12
# 16 	176   	1.03333e+11	-26.1488	1e+12
# 17 	174   	8e+10      	-26.1488	1e+12
# 18 	179   	4.33333e+10	-26.1488	1e+12
# 19 	176   	5e+10      	-26.1488	1e+12
# 20 	182   	4.66667e+10	-26.1488	1e+12
# 21 	194   	7e+10      	-26.1488	1e+12
# 22 	199   	4.66667e+10	-26.1488	1e+12
# 23 	194   	6.33333e+10	-26.1488	1e+12
# 24 	185   	5e+10      	-26.1488	1e+12
# 25 	186   	4.33333e+10	-26.1488	1e+12
# 26 	179   	4e+10      	-26.1488	1e+12
# 27 	191   	5e+10      	-26.1488	1e+12
# 28 	178   	6.33333e+10	-26.238 	1e+12
# 29 	171   	5e+10      	-26.238 	1e+12
# 30 	161   	5.66667e+10	-26.238 	1e+12
# 31 	167   	5e+10      	-26.238 	1e+12
# 32 	168   	4.66667e+10	-26.238 	1e+12
# 33 	186   	6.33333e+10	-26.2425	1e+12
# 34 	180   	4.33333e+10	-26.2425	1e+12
# 35 	182   	6.33333e+10	-26.2425	1e+12
# 36 	193   	6e+10      	-26.2479	1e+12
# 37 	172   	4.33333e+10	-26.2525	1e+12
# 38 	177   	7e+10      	-26.2525	1e+12
# 39 	198   	5e+10      	-26.2525	1e+12
# 40 	170   	6e+10      	-26.2525	1e+12
# 41 	182   	7.66667e+10	-26.2525	1e+12
# 42 	200   	6e+10      	-26.2525	1e+12
# 43 	173   	5.33333e+10	-26.2525	1e+12
# 44 	194   	5.33333e+10	-26.2525	1e+12
# 45 	169   	4.66667e+10	-26.2525	1e+12
# 46 	197   	4.33333e+10	-26.2525	1e+12
# 47 	198   	6e+10      	-26.2525	1e+12
# 48 	176   	4.66667e+10	-26.2525	1e+12
# 49 	184   	4.33333e+10	-26.2525	1e+12
# 50 	177   	6e+10      	-26.2525	1e+12
# 51 	175   	6.33333e+10	-26.2525	1e+12
# 52 	185   	6.33333e+10	-26.2525	1e+12
# 53 	187   	3.33333e+10	-26.2525	1e+12
# 54 	175   	5e+10      	-26.2525	1e+12
# 55 	208   	8.33333e+10	-26.2525	1e+12
# 56 	185   	3.66667e+10	-26.2525	1e+12
# 57 	174   	5.66667e+10	-26.2525	1e+12
# 58 	177   	5e+10      	-26.2525	1e+12
# 59 	182   	6e+10      	-26.2525	1e+12
# 60 	184   	5.66667e+10	-26.2525	1e+12
# 61 	177   	6.33333e+10	-26.2525	1e+12
# 62 	181   	6e+10      	-26.259 	1e+12
# 63 	181   	6.66667e+10	-26.259 	1e+12
# 64 	184   	5.66667e+10	-26.259 	1e+12
# 65 	196   	6e+10      	-26.259 	1e+12
# 66 	186   	8e+10      	-26.259 	1e+12
# 67 	177   	6.33333e+10	-26.259 	1e+12
# 68 	166   	7e+10      	-26.259 	1e+12
# 69 	192   	3.66667e+10	-26.259 	1e+12
# 70 	176   	3.33333e+10	-26.259 	1e+12
# 71 	158   	3.66667e+10	-26.259 	1e+12
# 72 	180   	5.33333e+10	-26.259 	1e+12
# 73 	168   	5e+10      	-26.259 	1e+12
# 74 	182   	5.33333e+10	-26.259 	1e+12
# 75 	183   	5.66667e+10	-26.259 	1e+12
# 76 	191   	3.66667e+10	-26.259 	1e+12
# 77 	182   	6e+10      	-26.259 	1e+12
# 78 	179   	5.33333e+10	-26.259 	1e+12
# 79 	175   	5.66667e+10	-26.259 	1e+12
# 80 	172   	7e+10      	-26.259 	1e+12
# 81 	182   	4.33333e+10	-26.259 	1e+12
# 82 	170   	5.33333e+10	-26.259 	1e+12
# 83 	182   	6.33333e+10	-26.259 	1e+12
# 84 	185   	5.33333e+10	-26.259 	1e+12
# 85 	184   	5.66667e+10	-26.259 	1e+12
# 86 	175   	3.33333e+10	-26.259 	1e+12
# 87 	188   	4.33333e+10	-26.259 	1e+12
# 88 	185   	6e+10      	-26.259 	1e+12
# 89 	174   	5.66667e+10	-26.259 	1e+12
# 90 	174   	7.66667e+10	-26.259 	1e+12
# 91 	171   	7.66667e+10	-26.259 	1e+12
# 92 	181   	4.66667e+10	-26.259 	1e+12
# 93 	162   	7.66667e+10	-26.259 	1e+12
# 94 	191   	4.66667e+10	-26.259 	1e+12
# 95 	179   	6.33333e+10	-26.259 	1e+12
# 96 	176   	6e+10      	-26.259 	1e+12
# 97 	167   	4e+10      	-26.259 	1e+12
# 98 	172   	5.66667e+10	-26.259 	1e+12
# 99 	198   	5.66667e+10	-26.259 	1e+12
# 100	180   	5.66667e+10	-26.259 	1e+12
# 101	185   	6.33333e+10	-26.259 	1e+12
# 102	178   	4.33333e+10	-26.259 	1e+12
# 103	171   	5.33333e+10	-26.259 	1e+12
# 104	190   	8e+10      	-26.259 	1e+12
# 105	170   	7.66667e+10	-26.259 	1e+12
# 106	177   	4.33333e+10	-26.259 	1e+12
# 107	194   	6e+10      	-26.259 	1e+12
# 108	156   	6.66667e+10	-26.259 	1e+12
# 109	183   	4.33333e+10	-26.259 	1e+12
# 110	178   	5e+10      	-26.259 	1e+12
# 111	187   	6e+10      	-26.259 	1e+12
# 112	179   	3.66667e+10	-26.259 	1e+12
# 113	191   	7.33333e+10	-26.259 	1e+12
# 114	171   	6e+10      	-26.259 	1e+12
# 115	190   	5e+10      	-26.259 	1e+12
# 116	175   	7e+10      	-26.259 	1e+12
# 117	179   	9e+10      	-26.259 	1e+12
# 118	155   	3.66667e+10	-26.259 	1e+12
# 119	175   	4.66667e+10	-26.259 	1e+12
# 120	185   	3.66667e+10	-26.259 	1e+12
# 121	180   	5e+10      	-26.259 	1e+12
# 122	189   	4.66667e+10	-26.259 	1e+12
# 123	189   	4e+10      	-26.259 	1e+12
# 124	185   	4.33333e+10	-26.259 	1e+12
# 125	180   	5e+10      	-26.259 	1e+12
# 126	200   	4e+10      	-26.259 	1e+12
# 127	173   	3.66667e+10	-26.259 	1e+12
# 128	150   	7e+10      	-26.259 	1e+12
# 129	183   	5e+10      	-26.259 	1e+12
# 130	167   	5.66667e+10	-26.259 	1e+12
# 131	182   	5.33333e+10	-26.259 	1e+12
# 132	181   	5.66667e+10	-26.259 	1e+12
# 133	181   	6e+10      	-26.259 	1e+12
# 134	182   	5.66667e+10	-26.259 	1e+12
# 135	175   	4.33333e+10	-26.259 	1e+12
# 136	182   	6.66667e+10	-26.259 	1e+12
# 137	154   	4.33333e+10	-26.259 	1e+12
# 138	159   	5e+10      	-26.259 	1e+12
# 139	206   	5.33333e+10	-26.259 	1e+12
# 140	176   	5.33333e+10	-26.259 	1e+12
# 141	178   	7.33333e+10	-26.259 	1e+12
# 142	193   	9.33333e+10	-26.259 	1e+12
# 143	197   	6.66667e+10	-26.259 	1e+12
# 144	167   	5e+10      	-26.259 	1e+12
# 145	184   	5e+10      	-26.259 	1e+12
# 146	186   	5.66667e+10	-26.259 	1e+12
# 147	185   	8e+10      	-26.259 	1e+12
# 148	178   	2.66667e+10	-26.259 	1e+12
# 149	166   	5.66667e+10	-26.259 	1e+12
# 150	178   	5e+10      	-26.259 	1e+12
# 151	179   	8.33333e+10	-26.259 	1e+12
# 152	169   	5.33333e+10	-26.259 	1e+12
# 153	160   	4e+10      	-26.259 	1e+12
# 154	175   	5e+10      	-26.259 	1e+12
# 155	173   	7.33333e+10	-26.259 	1e+12
# 156	169   	7e+10      	-26.259 	1e+12
# 157	212   	8e+10      	-26.259 	1e+12
# 158	170   	3.66667e+10	-26.259 	1e+12
# 159	172   	5.66667e+10	-26.259 	1e+12
# 160	182   	5e+10      	-26.259 	1e+12
# 161	175   	7.33333e+10	-26.259 	1e+12
# 162	167   	6e+10      	-26.259 	1e+12
# 163	177   	4e+10      	-26.259 	1e+12
# 164	185   	4.33333e+10	-26.259 	1e+12
# 165	170   	6e+10      	-26.259 	1e+12
# 166	179   	5e+10      	-26.259 	1e+12
# 167	186   	6.33333e+10	-26.259 	1e+12
# 168	188   	5e+10      	-26.259 	1e+12
# 169	186   	7e+10      	-26.259 	1e+12
# 170	165   	2.66667e+10	-26.259 	1e+12
# 171	162   	5.33333e+10	-26.259 	1e+12
# 172	168   	3e+10      	-26.259 	1e+12
# 173	178   	3.66667e+10	-26.259 	1e+12
# 174	183   	5.66667e+10	-26.259 	1e+12
# 175	182   	6e+10      	-26.259 	1e+12
# 176	191   	8.33333e+10	-26.259 	1e+12
# 177	187   	5.33333e+10	-26.259 	1e+12
# 178	170   	5.33333e+10	-26.259 	1e+12
# 179	193   	6.66667e+10	-26.259 	1e+12
# 180	175   	5e+10      	-26.259 	1e+12
# 181	171   	7e+10      	-26.259 	1e+12
# 182	175   	4.66667e+10	-26.259 	1e+12
# 183	179   	5.66667e+10	-26.259 	1e+12
# 184	165   	6e+10      	-26.259 	1e+12
# 185	185   	3.66667e+10	-26.259 	1e+12
# 186	200   	8e+10      	-26.259 	1e+12
# 187	176   	4.33333e+10	-26.259 	1e+12
# 188	174   	7e+10      	-26.259 	1e+12
# 189	182   	4.66667e+10	-26.259 	1e+12
# 190	185   	4.66667e+10	-26.259 	1e+12
# 191	161   	4e+10      	-26.259 	1e+12
# 192	190   	6e+10      	-26.259 	1e+12
# 193	172   	7.33333e+10	-26.259 	1e+12
# 194	165   	5.66667e+10	-26.259 	1e+12
# 195	174   	6.33333e+10	-26.259 	1e+12
# 196	172   	5.33333e+10	-26.259 	1e+12
# 197	182   	5.33333e+10	-26.259 	1e+12
# 198	180   	4e+10      	-26.259 	1e+12
# 199	181   	6e+10      	-26.259 	1e+12
# 200	184   	5e+10      	-26.259 	1e+12
# Best J: 1.1364468825233849
# Best RPM (n): 3319.1913918158584
# Best Diameter (D): 0.4176835461381057
# Best Pod: 1.255734561423683

# %%
# Prepare lists to store samples
J_samples = []
sigma_samples = []
pitch_samples = []
KT_samples = []
n1_samples = 20
n2_samples = 10
n3_samples = 21
sigma_list = [0.2,0.22,0.24,0.26,0.3,0.35,0.4,0.45,0.5]
sigma_array = np.array(sigma_list)
# Iterate over each combination of parameters
for J in np.linspace(0.5, 2.25, n1_samples):  # Assuming J varies between 0.5 and 2.25
    for sigma in sigma_array:  # Assuming sigma varies between 0.2 and 0.5
        for pitch in np.linspace(1.05, 2.08, n3_samples):  # Assuming pitch varies between 0.6 and 1.4
            # Prepare X1
            X1 = [J, 0.8, pitch, sigma]  # Assuming the order: [J, AE/A0, P/D, sigma]

            # Compute KT
            KT = calculate_Y2(C2, O2, a2, h2, D2, X1, E2, G2, L2)

            # Append to samples
            J_samples.append(J)
            sigma_samples.append(sigma)
            pitch_samples.append(pitch)
            KT_samples.append(KT)

len(KT_samples)
# Out:
# 3780

# %%
# Prepare lists to store samples
J_samples = []
sigma_samples = []
pitch_samples = []
KQ_samples = []
n1_samples = 20
n2_samples = 10
n3_samples = 21
sigma_list = [0.2,0.22,0.24,0.26,0.3,0.35,0.4,0.45,0.5]
sigma_array = np.array(sigma_list)
# Iterate over each combination of parameters
for J in np.linspace(0.5, 2.5, n1_samples):  # Assuming J varies between 0.5 and 2.25
    for sigma in sigma_array:  # Assuming sigma varies between 0.2 and 0.5
        for pitch in np.linspace(1.05, 2.08, n3_samples):  # Assuming pitch varies between 0.6 and 1.4
            # Prepare X1
            X1 = [J, 0.8, pitch, sigma]  # Assuming the order: [J, AE/A0, P/D, sigma]

            # Compute KQ
            KQ = calculate_Y1(C1, O1, a1, h1, D1, X1, E1, G1, L1)
            # Append to samples
            J_samples.append(J)
            sigma_samples.append(sigma)
            pitch_samples.append(pitch)
            KQ_samples.append(100*KQ)

len(KQ_samples)
# Out:
# 3780

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
# Convert lists to a 2D numpy array
X1_samples = np.array([J_samples, sigma_samples, pitch_samples]).T
y1_samples = np.array(KT_samples)

# Define the kernel function for the Gaussian Process
kernel = C(1.0, (1e-3, 1e3)) * RBF(1.0, (1e-3, 1e3))
print(X1_samples.shape)
# Initialize Gaussian Process
gp_KT = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=0.1, normalize_y=True)

# Fit the GP model to the data
gp_KT.fit(X1_samples, y1_samples)
# Out:
# (3780, 3)
# GaussianProcessRegressor(alpha=0.1, kernel=1**2 * RBF(length_scale=1),
#                          n_restarts_optimizer=10, normalize_y=True)

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C
# Convert lists to a 2D numpy array
X1_samples = np.array([J_samples, sigma_samples, pitch_samples]).T
y1_samples = np.array(KQ_samples)

# Define the kernel function for the Gaussian Process
kernel = C(1.0, (1e-3, 1e3)) * RBF(1.0, (1e-3, 1e3))

# Initialize Gaussian Process
gp_KQ = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10, alpha=0.1, normalize_y=True)

# Fit the GP model to the data
gp_KQ.fit(X1_samples, y1_samples)
# Out:
# GaussianProcessRegressor(alpha=0.1, kernel=1**2 * RBF(length_scale=1),
#                          n_restarts_optimizer=10, normalize_y=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of J and pod
J_range = np.linspace(0.5, 2.25, 20)
pod_range = np.linspace(1.05, 2.08, 21)

# Create a grid of J and pod values
J_grid, pod_grid = np.meshgrid(J_range, pod_range)

# Initialize arrays for KT_1 and KQ_1 values
KT_1_values = np.zeros_like(J_grid)
KQ_1_values = np.zeros_like(J_grid)

# Compute KT_1 and KQ_1 for each combination of J and pod
for i in range(J_grid.shape[0]):
    for j in range(J_grid.shape[1]):
        J = J_grid[i, j]
        pod = pod_grid[i, j]
        x = [J, 0.27,pod]  # Set sigma = 0.5
        X1 = np.array(x).reshape(1, -1)
        
        x1 = [J, 0.27,pod]  # Set sigma = 0.5
        X11 = np.array(x).reshape(1, -1)
        KT_1_values[i, j] = gp_KT.predict(X1)[0]
        KQ_1_values[i, j] = 10*gp_KQ.predict(X1)[0]

# Create 3D plots
fig = plt.figure(figsize=(12, 6))

# Plot for KT_1
ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_surface(J_grid, pod_grid, KT_1_values, cmap='viridis')
ax1.set_xlabel('J')
ax1.set_ylabel('pod')
ax1.set_zlabel('KT_1')
ax1.set_title('KT with sigma=0.27')
# Out:
# Text(0.5, 0.92, 'KT with sigma=0.27')

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of J and pod
J_range = np.linspace(0.5, 2.25, 20)
pod_range = np.linspace(1.05, 2.08, 21)

# Create a grid of J and pod values
J_grid, pod_grid = np.meshgrid(J_range, pod_range)

# Initialize arrays for KT_1 and KQ_1 values
KT_1_values = np.zeros_like(J_grid)
KQ_1_values = np.zeros_like(J_grid)

# Compute KT_1 and KQ_1 for each combination of J and pod
for i in range(J_grid.shape[0]):
    for j in range(J_grid.shape[1]):
        J = J_grid[i, j]
        pod = pod_grid[i, j]
        x = [J, 0.27,pod]  # Set sigma = 0.5
        X1 = np.array(x).reshape(1, -1)
        
        x1 = [J, 0.27,pod]  # Set sigma = 0.5
        X11 = np.array(x).reshape(1, -1)
        KT_1_values[i, j] = gp_KT.predict(X1)[0]
        KQ_1_values[i, j] = 10*gp_KQ.predict(X1)[0]

# Create 3D plots
fig = plt.figure(figsize=(12, 6))

# Plot for KT_1
ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_surface(J_grid, pod_grid, KT_1_values, cmap='viridis')
ax1.set_xlabel('J')
ax1.set_ylabel('pod')
ax1.set_zlabel('KT_1')
ax1.set_title('KT with sigma=0.27')
# Out:
# Text(0.5, 0.92, 'KT with sigma=0.27')

# %%
n_bounds = (50,3500)
def objective(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1 = np.array([J, sigma,pod]).reshape(1, -1)  # reshape is necessary for single sample prediction
    KT_1 = gp_KT.predict(X1)[0]  # get the predicted value
    KQ_1 = (gp_KQ.predict(X1)[0])/100 # get the predicted value
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T - 0.1*R:
        return 1e12  # Return a large value for excessive thrust
    if n>=3000:
        if P > Pmax:
            return 1e12  # Return a large negative value for excessive power
        return -V  # Negative sign to maximize speed
    if n<3000:
        if P> 100*n:
            return 1e12
        return -V

# Run the optimization process as before
result = differential_evolution(objective, bounds=[J_bounds, n_bounds, D_bounds, pod_bounds],maxiter =300,strategy='best1bin',callback = record_objective_value)
print(result)
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: -27.645925709253
#        x: [ 1.369e+00  3.006e+03  4.032e-01  1.580e+00]
#      nit: 93
#     nfev: 5745

# %%
for new_J in np.linspace(1.1,1.5,11):
    for new_pitch in np.linspace(1.3,1.7,10):
        for new_sigma in np.linspace(0.26,0.28,5):
            new_X1 = [new_J, 0.8, new_pitch, sigma]
            new_KT = calculate_Y2(C2, O2, a2, h2, D2, new_X1, E2, G2, L2)
            new_KQ = calculate_Y1(C1, O1, a1, h1, D1, new_X1, E1, G1, L1)
            J_samples.append(new_J)
            sigma_samples.append(new_sigma)
            pitch_samples.append(new_pitch)
            KT_samples.append(new_KT)
            KQ_samples.append(100*new_KQ)
            X_samples = np.array([J_samples, sigma_samples, pitch_samples]).T
            y1_samples = np.array(KT_samples)
            
            y2_samples = np.array(KQ_samples)
            
gp_KT.fit(X_samples, y1_samples)   
gp_KQ.fit(X_samples, y2_samples)
# Out:
# GaussianProcessRegressor(alpha=0.1, kernel=1**2 * RBF(length_scale=1),
#                          n_restarts_optimizer=10, normalize_y=True)

# %%
n_bounds = (3000,3500)
def objective(x):
    J, n, D, pod = x
    V = J * n * D/60
    patm=101300 
    rho=1025 
    g=9.81 
    h=1
    po=patm+rho*g*h
    pv =3200 
    sigma= (po-pv)/(0.5*rho*V**2)
    X1 = np.array([J, sigma,pod]).reshape(1, -1)  # reshape is necessary for single sample prediction
    KT_1 = gp_KT.predict(X1)[0]  # get the predicted value
    KQ_1 = (gp_KQ.predict(X1)[0])/100 # get the predicted value
    T = (KT_1 * rho * n**2 * D**4)/3600
    P = (KQ_1 * rho * n**3 * D**5*2*np.pi)/216000
    R = spline(V) 
    if R > T+0.1*R or R < T - 0.1*R:
        return 1e12  # Return a large value for excessive thrust
    if n>=3000:
        if P > Pmax:
            return 1e12  # Return a large negative value for excessive power
        return -V  # Negative sign to maximize speed
    if n<3000:
        if P> 100*n:
            return 1e12
        return -V

# Run the optimization process as before
result = differential_evolution(objective, bounds=[J_bounds, n_bounds, D_bounds, pod_bounds],maxiter =300,strategy='best1bin',callback = record_objective_value)
print(result)
# Out:
#  message: Optimization terminated successfully.
#  success: True
#      fun: 1000000000000.0
#        x: [ 1.996e+00  3.096e+03  4.659e-01  1.870e+00]
#      nit: 1
#     nfev: 125

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
X11 = np.zeros(4)
# Define the range of J and pod
J_range = np.linspace(0.5, 2.25, 20)
pod_range = np.linspace(1.05, 2.08, 11)

# Create a grid of J and pod values
J_grid, pod_grid = np.meshgrid(J_range, pod_range)

# Initialize arrays for KT_1 and KQ_1 values
KT_1_values_gp_KT = np.zeros_like(J_grid)
KT_1_values_calculate_Y2 = np.zeros_like(J_grid)
difference_values = np.zeros_like(J_grid)

# Compute KT_1 for each combination of J and pod using both methods
for i in range(J_grid.shape[0]):
    for j in range(J_grid.shape[1]):
        J = J_grid[i, j]
        pod = pod_grid[i, j]
        X = np.array([J, 0.27, pod]).reshape(1, -1)
        
        # Get prediction from gp_KT
        KT_1_values_gp_KT[i, j] = gp_KT.predict(X)[0]
        X11[1] = 0.8
        X11[2] = pod
        X11[3] = 0.27
        X11[0] = J
        # Get prediction from calculate_Y2
        # (Please replace below line with appropriate calculate_Y2 function)
        KT_1_values_calculate_Y2[i, j] = calculate_Y2(C2, O2, a2, h2, D2, X11, E2, G2, L2)

        # Calculate difference
        difference_values[i, j] = KT_1_values_gp_KT[i, j] - KT_1_values_calculate_Y2[i, j]
        
# Create 3D plots
fig = plt.figure(figsize=(12, 6))

# Plot for difference
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(J_grid, pod_grid, difference_values, cmap='viridis', alpha=0.5)

# Quiver plot (Needle plot)
ax.quiver(J_grid, pod_grid, np.zeros_like(J_grid), 
          np.zeros_like(J_grid), np.zeros_like(J_grid), difference_values, 
          color='r', length=0.05, normalize=True)
ax.set_zticks([-0.15,-0.10, -0.05, 0, 0.05, 0.10])
ax.set_xlabel('J')
ax.set_ylabel('pod')
ax.set_zlabel('Difference')
ax.set_title('Difference between surrogate and parametric predictions for 4000 samples')

plt.show()
